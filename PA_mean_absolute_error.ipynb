# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/ccai2023/blob/main/PA_mean_absolute_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Administrative setup
#
# - Execute code below to mount drive, install packages, and download resources.
#
# - Click on these buttons when the 2 pop-up windows show up:
#
# <img src="https://raw.githubusercontent.com/lisatwyw/CS4SocialGood/main/ccai/Mount.png" width="500"/>

# %%
# mount drive for permanent storage

import os, sys
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

try:
  # !mkdir /content/drive/MyDrive/purple_air
  # !mkdir /content/drive/MyDrive/purple_air/packages
except:
  pass

os.chdir('/content/drive/MyDrive/purple_air/')
nb_path = 'mypackages'

try:
  # create symbolic path
  os.symlink('/content/drive/MyDrive/purple_air/packages', nb_path)

  # install once to symbolic path
  # !pip install --target=$nb_path lale
  # !pip install --target=$nb_path daymetpy
  # !pip install --target=$nb_path geomdl
  #!pip install --target=$nb_path -U fastapi python-multipart uvicorn kaleido
  # !pip install --target=$nb_path -U plotly
except:
  pass

sys.path.insert(0, '/content/drive/MyDrive/purple_air/')

# !ls /content/drive/MyDrive/purple_air/
# Out:
# Mounted at /content/drive
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# mkdir: cannot create directory ‘/content/drive/MyDrive/purple_air’: File exists
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# mkdir: cannot create directory ‘/content/drive/MyDrive/purple_air/packages’: File exists
# 'Copy of PA_Oakland_2012_daily.csv'   PA_data_for_modeling_2017.csv
# 'Copy of PA_Oakland_2013_daily.csv'   PA_data_for_modeling_2018.csv
# 'Copy of PA_Oakland_2014_daily.csv'   PA_data_for_modeling_2019.csv
# 'Copy of PA_Oakland_2015_daily.csv'   PA_data_for_modeling_2020.csv
# 'Copy of PA_Oakland_2016_daily.csv'   PA_data_for_modeling_2021.csv
# 'Copy of PA_Oakland_2017_daily.csv'   PA_data_for_modeling_2022.csv
# 'Copy of PA_Oakland_2018_daily.csv'   PA_Oakland_2012_daily.csv
# 'Copy of PA_Oakland_2019_daily.csv'   PA_Oakland_2013_daily.csv
# 'Copy of PA_Oakland_2020_daily.csv'   PA_Oakland_2014_daily.csv
# 'Copy of PA_Oakland_2021_daily.csv'   PA_Oakland_2015_daily.csv
#  Lat_long_PA_sensors_full.csv	      PA_Oakland_2016_daily.csv
#  model.py			      PA_Oakland_2017_daily.csv
#  mypackages			      PA_Oakland_2018_daily.csv
#  Oakland_daily_daymet_data_2017.csv   PA_Oakland_2019_daily.csv
#  Oakland_daily_daymet_data_2018.csv   PA_Oakland_2020_daily.csv
#  Oakland_daily_daymet_data_2019.csv   PA_Oakland_2021_daily.csv
#  Oakland_daily_daymet_data_2020.csv   __pycache__
#  Oakland_daily_daymet_data_2021.csv   visualization-3.py
#  packages

# %% [markdown]
# ## Check for the precomputed files...

# %% [markdown]
# ```
# Collecting daymetpy
#   Downloading daymetpy-1.0.0.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: daymetpy
#   Building wheel for daymetpy (setup.py) ... done
#   Created wheel for daymetpy: filename=daymetpy-1.0.0-py3-none-any.whl size=4094 sha256=02cba4ef9e6a078a65eae7b80e803da850cb9a51ee06f8d896a974e9ad6c5fca
#   Stored in directory: /root/.cache/pip/wheels/56/d2/10/a37e259b28ccac8537185688acfb45913df0b826d5ad3962d7
# Successfully built daymetpy
# Installing collected packages: daymetpy
# Successfully installed daymetpy-1.0.0
#
#
# Collecting geomdl
#   Downloading geomdl-5.3.1-py2.py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: geomdl
# Successfully installed geomdl-5.3.1
#
#
#
# Collecting fastapi
#   Using cached fastapi-0.104.0-py3-none-any.whl (92 kB)
# Collecting python-multipart
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# Collecting uvicorn
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting kaleido
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Collecting anyio<4.0.0,>=3.7.1 (from fastapi)
#   Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi)
#   Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi)
#   Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting click>=7.0 (from uvicorn)
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting h11>=0.8 (from uvicorn)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting idna>=2.8 (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio>=1.1 (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached pydantic_core-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Installing collected packages: kaleido, typing-extensions, sniffio, python-multipart, idna, h11, exceptiongroup, click, annotated-types, uvicorn, pydantic-core, anyio, starlette, pydantic, fastapi
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed annotated-types-0.6.0 anyio-3.7.1 click-8.1.7 exceptiongroup-1.1.3 fastapi-0.104.0 h11-0.14.0 idna-3.4 kaleido-0.2.1 pydantic-2.4.2 pydantic-core-2.10.1 python-multipart-0.0.6 sniffio-1.3.0 starlette-0.27.0 typing-extensions-4.8.0 uvicorn-0.23.2
#
# ```

# %%
import requests
import pandas as pd # circular imports?

from datetime import datetime
import time
import json
import io
from io import StringIO
import geopandas
import matplotlib.pyplot as plt
from matplotlib import cm

import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import MarkerCluster, BeautifyIcon
import branca

# Import the daymetpy package
# import daymetpy

# Import packages for multiprocessing
import itertools
import multiprocessing as mp
from multiprocessing.pool import ThreadPool

from shapely.geometry import Point, Polygon

import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn' # You can turn off these warnings if you know what you are doing by using
import polars as pol

import math
import numpy as np

# %% [markdown]
# ## 2a. Steps to download PurpleAir
#
# 1. Visit [this page](https://develop.purpleair.com/keys)
# 2. Click "Add" button (top left)
# 3. Click "Add" button (bottom right)
#
# ![image](https://global.discourse-cdn.com/business7/uploads/purpleair/optimized/2X/d/d47145bfc7631a5b48b6aa006c320562a04358ac_2_690x318.png)

# %%
# !curl -X GET "https://api.purpleair.com/v1/keys" -H "X-API-Key: xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxx"
# Out:
# {
#   "api_version" : "V1.0.11-0.0.49",
#   "time_stamp" : 1697774372,
#   "error" : "ApiKeyInvalidError",
#   "description" : "The provided api_key was not valid."
# }

# %%
# !curl -X GET "https://api.purpleair.com/v1/keys"
# Out:
# {
#   "api_version" : "V1.0.11-0.0.49",
#   "time_stamp" : 1697774372,
#   "error" : "ApiKeyMissingError",
#   "description" : "No API key was found in the request."
# }

# %% [markdown]
# # 2b. Read in the pre-downloaded and merged dataframe

# %%
YEAR = 2022

pa_df = pd.read_csv(f'PA_data_for_modeling_{YEAR}.csv')
sensor_list1 = pa_df.drop_duplicates(subset=['latitude', 'longitude'], keep='last') # latest snapshot
sensor_list = pa_df.drop_duplicates(subset=['latitude', 'longitude'], keep='first') # earliest snapshot

key_to_predict ='pm10.0_atm'
max_value = pa_df[key_to_predict ].max()
min_value = pa_df[key_to_predict ].min()
print( min_value, max_value )
nlevels = 5 # color levels
# define colours for each level
ss_colors=['#ff00ff', '#ff40bf', '#ff807f', '#ffc03f', '#ffff00']

mx, mn = np.int64(max_value) -1,  np.int64(min_value)
sensor_list.head()
# Out:
# 0.0 3356.8825
#       Unnamed: 0  sensor                      name   latitude  longitude  \
# 0              0   13997                   Hilltop  37.834310 -122.22653
# 365          365   15645  Redwood Heights, Oakland  37.801030 -122.18855
# 730          730   17927              West Oakland  37.817640 -122.27246
# 1095        1095   18997         Head-Royce School  37.808174 -122.20474
# 1460        1460   19273                Sims Drive  37.821156 -122.20937
#
#        Datestamp   humidity  temperature     pressure  pm10.0_atm  \
# 0     2022-01-01  45.919000    52.233000   996.909000      3.8495
# 365   2022-01-01  43.398000    55.553000  1003.290000      3.7900
# 730   2022-01-01  63.971281    64.467907   998.648163      8.9030
# 1095  2022-01-01  48.510000    52.771000  1005.613000      4.1550
# 1460  2022-01-01  48.233000    51.056000   997.452000      2.5380
#
#       pm10.0_cf_1  prcp    srad
# 0          3.9565   0.0  219.00
# 365        3.7900   0.0  227.48
# 730        8.9205   0.0  216.46
# 1095       4.1550   0.0  224.64
# 1460       2.5385   0.0  220.62

# %%
from folium.features import DivIcon

def draw( sensor_list, ss_filtered_legend_index, annotate=True, description='first' ):
  # create nao
  map = folium.Map(location=[sensor_list['latitude'].mean(), sensor_list['longitude'].mean()], zoom_start=13, control_scale=True)

  # add annotations on the map

  # - for each sensor location, add diamond whose size represents measured value
  for index, row in sensor_list.iterrows():
      local_deformation = math.cos(row['latitude'] * math.pi / 180)
      size = row[ key_to_predict ]*60/max_value * local_deformation

      folium.features.RegularPolygonMarker(
                  location =[row['latitude'], row['longitude']],
                  radius   = size,
                  fill_color=ss_colors[row['color_labels']],
                  color = ss_colors[row['color_labels']],
      ).add_to(map)

      if annotate:
        folium.map.Marker( [row['latitude'], row['longitude']],
                  icon=DivIcon(
                  icon_size=(250,36),
                  icon_anchor=(0,0),
                  html='<div style="font-size: 4pt">%s</div>'% row['sensor'] )
        ).add_to(map)

  sw = sensor_list[['latitude', 'longitude']].min().values.tolist()
  ne = sensor_list[['latitude', 'longitude']].max().values.tolist()

  # # Get maximum quantity of emissions from stationary source
  colormap = branca.colormap.LinearColormap(ss_colors,
                                            index=ss_filtered_legend_index[1:],
                                            vmin=0, vmax=max_value,
                                            caption= f'{key_to_predict} measured on {description} day' )
  colormap.add_to(map)
  if 1:
    svg_style = '<style>svg#legend {font-size: 14px; background-color: white;}</style>'
    map.get_root().header.add_child(folium.Element(svg_style))

  bw = 0.005 # width of bounding box
  map.fit_bounds([ [sw[0]-bw,sw[1]-bw], [ne[0]+bw, ne[1]+bw] ] )
  return map


sensor_list['color_labels'] = pd.cut(sensor_list[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[0]
ss_filtered_legend_index = pd.cut(sensor_list[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[1]
map0 = draw( sensor_list, ss_filtered_legend_index )


sensor_list1['color_labels'] = pd.cut(sensor_list1[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[0]
ss_filtered_legend_index1 = pd.cut(sensor_list1[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[1]
map1 = draw( sensor_list1, ss_filtered_legend_index1, True, 'last' )

from IPython.core.display import display, HTML
#from IPython.display import IFrame

htmlmap = HTML('<iframe srcdoc="{}" style="float:left; width: {}px; height: {}px; display:inline-block; width: 50%; margin: 0 auto; border: 0px solid black"></iframe>'
           '<iframe srcdoc="{}" style="float:right; width: {}px; height: {}px; display:inline-block; width: 50%; margin: 0 auto; border: 0px solid black"></iframe>'
           .format(map0.get_root().render().replace('"', '&quot;'),100, 300,
                   map1.get_root().render().replace('"', '&quot;'),100, 300))
display(htmlmap)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe srcdoc="<!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#     <style>svg#legend {font-size: 14px; background-color: white;}</style>
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_c497aea8edd1b03deb06abb0734048d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;></script>
# </head>
# <body>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_c497aea8edd1b03deb06abb0734048d6&quot; ></div>
#
# </body>
# <script>
#
#
#             var map_c497aea8edd1b03deb06abb0734048d6 = L.map(
#                 &quot;map_c497aea8edd1b03deb06abb0734048d6&quot;,
#                 {
#                     center: [37.79476809189189, -122.21982534054055],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#
#
#
#             var tile_layer_48772c22e6b45eebf9fc813f603cb4f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var regular_polygon_marker_54cf4d6f23d649f4d2377e2d2fc06906 = new L.RegularPolygonMarker(
#                 [37.83431, -122.22653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.05434128221704802, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var marker_32418cd2fb533d8ed47bd73a23256747 = L.marker(
#                 [37.83431, -122.22653],
#                 {}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var div_icon_18eda1fce40b26dd77f96368e4cdea3a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e13997\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_32418cd2fb533d8ed47bd73a23256747.setIcon(div_icon_18eda1fce40b26dd77f96368e4cdea3a);
#
#
#             var regular_polygon_marker_0e153a777e8a9ce5056e2d064ec4bbb8 = new L.RegularPolygonMarker(
#                 [37.80103, -122.18855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0535254791476388, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var marker_33f9c03f91f01656cb1465f66a152d33 = L.marker(
#                 [37.80103, -122.18855],
#                 {}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var div_icon_16be50f1eb806d33b9868c7cfad970b8 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e15645\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_33f9c03f91f01656cb1465f66a152d33.setIcon(div_icon_16be50f1eb806d33b9868c7cfad970b8);
#
#
#             var regular_polygon_marker_2699b7b6a6f37df8397219698c10d879 = new L.RegularPolygonMarker(
#                 [37.81764, -122.27246],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12570716581573485, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var marker_55065b872dfde9e139fb212cf81c5cc6 = L.marker(
#                 [37.81764, -122.27246],
#                 {}
#             ).addTo(map_c497aea8edd1b03deb06abb0734048d6);
#
#
#             var div_icon_6e58eefbbc93d5759ff5e9ba3fea4544 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e17927\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_55065b872dfde9e139fb212cf81c5cc6.setIcon(div_icon_6e58eefbbc93d5759ff5e9ba3fea4544);

# %% [markdown]
# # Naive surface-fitting

# %%
# %matplotlib inline

MAP_WIDTH, MAP_HEIGHT = 300, 100
x = ((MAP_WIDTH/360.0) * (180 + sensor_list.latitude.values ));   # translate x and rescaled
y = ((MAP_HEIGHT/180.0) * (90 - sensor_list.longitude.values ));  # reflect y and rescaled

plt.scatter( x, y, color='red' )
plt.figure()
plt.scatter( sensor_list.latitude.values, sensor_list.longitude.values )

# %%
# %matplotlib inline

import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# test function
def function(data, p00, p10, p01, p20, p11, p02, p21, p12, p03 ):
    x = data[0]
    y = data[1]
    d = p00 + p10*x + p01*y + p20*(x**2) + p11*x*y + p02*(y**2) + p21*(x**2)*y + p12*x*(y**2) + p03*(y**3)
    return d

#x_data = sensor_list.latitude
#y_data = sensor_list.longitude
x_data = ((MAP_WIDTH/360.0) * (180 + sensor_list.latitude));
y_data = ((MAP_HEIGHT/180.0) * (90 - sensor_list.longitude));
z_data = sensor_list[ key_to_predict ]

# get fit parameters from scipy curve fit
parameters, covariance = curve_fit(function, [x_data, y_data], z_data)

# create surface function model
# setup data points for calculating surface model
model_x_data = np.linspace(min(x_data), max(x_data), 30)
model_y_data = np.linspace(min(y_data), max(y_data), 30)

# create coordinate arrays for vectorized evaluations
X, Y = np.meshgrid(model_x_data, model_y_data)

# calculate Z coordinate array
Z = function(np.array([X, Y]), *parameters)

# setup figure object
fig = plt.figure()
ax = plt.axes(projection ="3d")
ax.scatter3D(x_data, y_data, z_data, color = "blue")
ax.scatter3D(X, Y, Z, color = "red")

# %%
parameters
# Out:
# array([-2.39207223e+06, -4.15825446e+02,  1.26940571e+04,  2.11093395e+02,
#        -3.45833002e+02,  3.31416195e+02, -5.22962143e+01,  1.58527078e+02,
#        -1.22053456e+02])

# %%
Z_est = function(np.array([x_data, y_data]), *parameters)
rmse = np.sqrt( np.mean( (Z_est - z_data)**2 ))
rmse
# Out:
# 267.7010773028493

# %% [markdown]
# ## Distances between pairs of sensors

# %%
from sklearn.metrics.pairwise import euclidean_distances
import seaborn as sns

n=sensor_list.shape[0]
dist = np.zeros( (n,n) )
for a,(lat1,long1) in enumerate( zip( list(sensor_list.latitude.values), list(sensor_list.longitude.values) ) ):
    for b,(lat2,long2) in enumerate( zip( list(sensor_list.latitude.values), list(sensor_list.longitude.values) ) ):
      if (a != b):
        # ACOS( SIN(lat1)*SIN(lat2) + COS(lat1)*COS(lat2)*COS(lon2-lon1) ) * 6371000
        d=np.arccos( np.sin(lat1)*np.sin(lat2) + np.cos( lat1)*np.cos(lat2) *np.cos(long1-long2) ) * 6371000
        dist[a,b]= dist[b,a] = d

sns.heatmap( dist )
#plt.imshow(dist)
# Out:
# <Axes: >

# %%
j=1

s1=sensor_list['sensor'].values[j]
q = np.argmax( dist[:, j ] )
s2=sensor_list['sensor'].values[q]

# %% [markdown]
# # Starter's benchmark
#
#
# Goal of this section is to setup a forecast formulation:
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i )$
#
# where $y_i^{t+1}$ is the measured PM10 for sensor $i$ at time $t$+1 given measurements made from timepoints 1 to $t$
#
#
# At the end of this section, we compare performances of different RNN architectures and examine the effects of inclusions of other time-series, e.g.
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i , \text{radiation}_i^{1:t} )$
#
# ...
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i , \text{radiation}_i^{1:t}, \text{temperature}_i^{1:t}, \text{pressure}_i^{1:t} )$

# %%
grps=pa_df.groupby( by='sensor')
grps.groups.keys()
# Out:
# dict_keys([13997, 15645, 17927, 18997, 19273, 19275, 19299, 19471, 19509, 19664, 20747, 20951, 21285, 22067, 22423, 27135, 34923, 36111, 36153, 37149, 37311, 37491, 37693, 38193, 38613, 38683, 38849, 40059, 41503, 46127, 46331, 50377, 52995, 53219, 53917, 55183, 55811, 55817, 55915, 55961, 55991, 56071, 56281, 59649, 59737, 59921, 60025, 60167, 60333, 60653, 60711, 61359, 61423, 61621, 62303, 62363, 63257, 63509, 63553, 63605, 63849, 63981, 64063, 64429, 64953, 65225, 65251, 65375, 65787, 65849, 65867, 66155, 67261, 67265, 67325, 67359, 67787, 67801, 67943, 67951, 68657, 68711, 68943, 69121, 69131, 69235, 69323, 69587, 69851, 69919, 70015, 70109, 70117, 70663, 70669, 71453, 71461, 71797, 72609, 73149, 73231, 73565, 74161, 74481, 75223, 76071, 76125, 77149, 77397, 77703, 77887, 78475, 80799, 80833, 81017, 81245, 82055, 82105, 83191, 83449, 83737, 84197, 84395, 84721, 84923, 85165, 85357, 85571, 85591, 85835, 87307, 92097, 93855, 95573, 96173, 96309, 97215, 98099, 101515, 103290, 103850, 103852, 105206, 106120, 107652, 108628, 109324, 110306, 110480, 110985, 111530, 111686, 112008, 112308, 112478, 112488, 113222, 113346, 113414, 113608, 114189, 115633, 116023, 116097, 116153, 116229, 116431, 117015, 117935, 117971, 118973, 118977, 119005, 119485, 119607, 119647, 120669, 121107, 121427, 122013, 122061, 126137, 126591, 131817, 137014])

# %%
# sensor lists are identical during this year if the intersection is empty
np.setdiff1d( sensor_list.sensor, sensor_list1.sensor )
# Out:
# array([], dtype=int64)

# %%
if 0:
  s1,s2=13997, 15645 # neighbouring sensors
  s1,s2=87307, 82105 # neighbouring sensors
  s1,s2=87307, 17927 # distant neighbours
  s1,s2=87307, 17927 # distant neighbours

# %%
key_to_predict = 'pm10.0_atm'

print( pa_df.loc[ grps.groups[s1] ][ ['latitude','longitude'] ].head(1) )
print( pa_df.loc[ grps.groups[s2] ][ ['latitude','longitude'] ].head(1) )

xx = np.arange(365)

plt.plot( xx, pa_df.loc[grps.groups[s1]][ key_to_predict ], color='blue')
plt.plot( xx, pa_df.loc[grps.groups[s2]][ key_to_predict ], color='cyan')
# Out:
#      latitude  longitude
# 365  37.80103 -122.18855
#         latitude  longitude
# 60590  37.787052 -122.30934

# %% [markdown]
# # 4a. Develop and evaluate univariate forecast models

# %% [markdown]
# ## Example experimenal setup
#
# | | | |
# | :-- | :-- | :-- |
# | Sensor 1 | TRN | VAL |
# | Sensor 2 | TST  |

# %%
trn = pa_df.loc[grps.groups[s1]].iloc[0:365//3,:]
val = pa_df.loc[grps.groups[s1]].iloc[(365//3):(2*365//3),: ]

trn.head(2)
# Out:
#      Unnamed: 0  sensor                      name  latitude  longitude  \
# 365         365   15645  Redwood Heights, Oakland  37.80103 -122.18855
# 366         366   15645  Redwood Heights, Oakland  37.80103 -122.18855
#
#       Datestamp  humidity  temperature  pressure  pm10.0_atm  pm10.0_cf_1  \
# 365  2022-01-01    43.398       55.553  1003.290       3.790        3.790
# 366  2022-01-02    40.700       55.214  1008.911       6.218        6.218
#
#      prcp    srad
# 365   0.0  227.48
# 366   0.0  259.95

# %%
trn.tail(2)
# Out:
#      Unnamed: 0  sensor                      name  latitude  longitude  \
# 484         484   15645  Redwood Heights, Oakland  37.80103 -122.18855
# 485         485   15645  Redwood Heights, Oakland  37.80103 -122.18855
#
#       Datestamp  humidity  temperature  pressure  pm10.0_atm  pm10.0_cf_1  \
# 484  2022-04-30    42.798       69.854  1001.959       4.762        4.762
# 485  2022-05-01    45.395       66.350   998.348       5.561        5.561
#
#      prcp    srad
# 484   0.0  441.63
# 485   0.0  511.58

# %%
# %%time

# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

import tensorflow as tf

from numpy import array
import keras
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, GRU
from keras.layers import Dense

from keras.layers import Bidirectional
import scipy
from sklearn.preprocessing import StandardScaler

def eval_model(model, X, Y ):
  m1,m2,m3=[],[],[]
  t='tst'
  yhat = model.predict(X[t], verbose=0)
  spearman_stats=scipy.stats.spearmanr( Y[t], yhat.squeeze(), )
  delta = np.abs(Y[t]- yhat.squeeze() )
  MdAE = np.median( delta )
  RMSE = np.sqrt( np.mean( delta**2 ))
  print( f'{t}, MdAE={MdAE:.3f}, RMSE={RMSE:.3f}, Spearman={spearman_stats[0]:.3f}' )
  if len(m1)==0:
    return spearman_stats[0], MdAE, RMSE
  else:
    m1.append( spearman_stats[0] )
    m2.append( MdAE )
    m3.append( RMSE )
    return np.array(m1), np.array(m2), np.array(m3)

def train_eval_univariate(s1, s2, mid = 'lstm-uni', k = 'pm10.0_atm' ):

  # split a univariate sequence into samples
  def split_sequence(sequence, n_days, S=None):

    sequence=sequence.reshape(-1,1) # for rescaling 1D

    if suffix == '-':
      S = None
    else:
      if S is None:
        if suffix == '-SC1':
          S = StandardScaler()
        elif suffix == '-SC2':
          S = Pipeline( [('standardizer', StandardScaler()), ('scaler', MinMaxScaler())]  )
        sequence = S.fit_transform( sequence )
      else:
        sequence = S.transform(sequence)

    X, y = list(), list()
    for i in range(len(sequence)):
      # find the end of this pattern
      end_ix = i + n_days
      # check if we are beyond the sequence
      if end_ix > len(sequence)-1:
        break
      # gather input and output parts of the pattern
      seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
      X.append(seq_x)
      y.append(seq_y)

    return np.array(X), np.array(y), S


  # split the 1d sequence into forecasting training set
  X,Y={},{}

  print( f'Train using data from first {n_days}; early stop using data from next {n_days}; test on a different sensor')

  trn = pa_df.loc[grps.groups[s1]][key_to_predict][0:365//3].values
  val = pa_df.loc[grps.groups[s1]][key_to_predict][(365//3):(2*365//3)].values

  # test on a different sensor
  tst = pa_df.loc[grps.groups[s2]][key_to_predict].values

  t='trn'; X[t], Y[t], Scaler = split_sequence(trn, n_days)
  t='val'; X[t], Y[t], _ = split_sequence(val, n_days, Scaler)
  t='tst'; X[t], Y[t], _ = split_sequence(tst, n_days, Scaler)

  # no longer true after rescaling...
  # t='trn'; assert trn[:n_days+1][-1] == Y[t][0]   #  trn[:15] is a concatenation of  X[t][0] and Y[t][0]

  model = Sequential()
  if 'bi' in mid:
    model.add(Bidirectional( LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features))) )
    model.add(Bidirectional( LSTM(50, activation='relu', ) ))
  else:
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features)) )
    model.add(LSTM(50, activation='relu'))

  model.add(Dense(1))

  LR=0.0001
  opt = keras.optimizers.Adam(learning_rate=LR )
  model.compile(optimizer=opt, loss=LOSS )

  C = []
  C.append( tf.keras.callbacks.EarlyStopping(monitor="val_loss",
            min_delta=0,
            patience=0,
            verbose=0,
            mode="auto",
            baseline=None,
            restore_best_weights=False,
            start_from_epoch=0,)
  )
  t='trn'
  h = model.fit(X[t], Y[t], validation_data=(X['val'], Y['val']), epochs=5000, verbose=0, callbacks=C)
  hist = h.history

  for kk in hist.keys():
    plt.plot( hist[kk], label=kk )
  plt.title( mid )
  plt.legend()
  return model, X, Y







n_days, n_features = 14, 1 # 2-week period

LOSS='mean_squared_logarithmic_error'
LOSS='mean_absolute_percentage_error'
LOSS='mean_absolute_error'

Res_DF=pd.DataFrame( columns=['setting', 'R2', 'RMSE', 'MdAE'] )

for suffix in ['-','-SC1','-SC2']:
  for mid in [f'bilstm-uni', f'lstm-uni']:
    model, X, Y, = train_eval_univariate(s1, s2, mid )
    a,b,c = eval_model(model, X, Y )
    Res_DF.loc[len(Res_DF)] = np.array( [mid+suffix, a,b,c])

Res_DF.head(1000)
# Out:
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=5.255, RMSE=14.598, Spearman=0.437
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=5.534, RMSE=15.358, Spearman=0.359
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.570, RMSE=1.484, Spearman=0.404
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.545, RMSE=1.322, Spearman=0.372
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.125, RMSE=0.294, Spearman=0.392
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.121, RMSE=0.290, Spearman=0.377
# CPU times: user 1min 43s, sys: 1.34 s, total: 1min 45s
# Wall time: 2min 3s
#           setting                   R2                 RMSE  \
# 0     bilstm-uni-  0.43716637946535397    5.254708492279053
# 1       lstm-uni-   0.3585883914779213    5.534383603096009
# 2  bilstm-uni-SC1   0.4042753656016376   0.5701280960393378
# 3    lstm-uni-SC1   0.3723851569747427   0.5453065318320063
# 4  bilstm-uni-SC2  0.39155932546036903  0.12468282193059682
# 5    lstm-uni-SC2   0.3772607004679726  0.12122208986971672
#
#                   MdAE
# 0   14.598400217049978
# 1    15.35849902004309
# 2    1.483672268812202
# 3   1.3221046413722144
# 4  0.29368492821946257
# 5   0.2898449063265286

# %% [markdown]
# # 4b. Develop and evaluate multi-variable forecast models

# %%
Res_DF
# Out:
#           setting                   R2                 RMSE  \
# 0     bilstm-uni-  0.43716637946535397    5.254708492279053
# 1       lstm-uni-   0.3585883914779213    5.534383603096009
# 2  bilstm-uni-SC1   0.4042753656016376   0.5701280960393378
# 3    lstm-uni-SC1   0.3723851569747427   0.5453065318320063
# 4  bilstm-uni-SC2  0.39155932546036903  0.12468282193059682
# 5    lstm-uni-SC2   0.3772607004679726  0.12122208986971672
#
#                   MdAE
# 0   14.598400217049978
# 1    15.35849902004309
# 2    1.483672268812202
# 3   1.3221046413722144
# 4  0.29368492821946257
# 5   0.2898449063265286

# %%
# %%time

from tensorflow.keras.layers import Reshape, Dense, Flatten, Dropout, MaxPooling1D, TimeDistributed, LSTM, BatchNormalization, Input, concatenate, Conv1D

# create multi-variable time-series
def split_df( df, n_days, kk, k, S=None ):
  df = df[ kk ]
  if suffix == '-':
    S=None
    print('dont preprocess')
  else:
    if S is None:
      if suffix =='-SC1':
        S = StandardScaler()
      elif suffix=='-SC2':
        S = Pipeline( [('standardizer', StandardScaler()), ('scaler', MinMaxScaler())] )
      S.fit( df )
    XX = S.fit_transform( df )
    df[ kk ]= XX

  X, y = list(), list()
  n= len(df)

  for i in range(n):
    # find the end of this pattern
    end_ix = i + n_days
    # check if we are beyond the sequence
    if end_ix > len(df)-1:
      break
    # gather input and output parts of the pattern
    seq_x = df.iloc[i:end_ix, : ].values
    seq_y = df.iloc[end_ix, 0 ]
    X.append(seq_x)
    y.append(seq_y)

  return np.array(X), np.array(y), S



def train_eval_multi(s1, s2, L, k = 'pm10.0_atm'):

  n_days, n_features = 14, len(L) # 2-week

  print('window size of', n_days, 'days', n_features , 'features')

  # split the 1d sequence into forecasting training set
  X,Y={},{}

  trn = pa_df.loc[grps.groups[s1]][:365//3]
  val = pa_df.loc[grps.groups[s1]][365//3:(365//3*2)]

  t='trn'; X[t], Y[t], Scaler = split_df(trn, n_days, L, L[0] )
  t='val'; X[t], Y[t], _ = split_df(val, n_days, L, L[0], Scaler )

  # test on a different sensor
  tst = pa_df.loc[grps.groups[s2]]
  t='tst'; X[t], Y[t], _ = split_df( tst, n_days, L, L[0], Scaler )

  #t='trn'; assert Scaler.transform( trn[L] )[n_days, 0 ] == Y[t][0]  #  trn[:15] is a concatenation of  X[t][:14] and Y[t][0]

  # https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

  for t in ['trn','val','tst']:
    n_subsamples = 2
    n_days2 = n_days// n_subsamples
    if 'cnn' in mid:
      nd = n_days*n_features
      X[t] = X[t].reshape( (X[t].shape[0], nd ))

  model2 = Sequential()
  if 'bi' in mid:
    model2.add( Bidirectional(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features))) )
    model2.add( Bidirectional(LSTM(50, activation='relu')) )
  elif 'cnn' in mid:
    model2.add( Reshape((n_days, n_features), input_shape=(nd,)))
    model2.add( Conv1D(14, kernel_size=3, activation='relu'))
    model2.add( Conv1D(14, kernel_size=3, activation='relu'))
    model2.add( BatchNormalization())
    model2.add( MaxPooling1D(pool_size=2) )
    model2.add( Flatten())
  else:
    model2.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features)))
    model2.add(LSTM(50, activation='relu'))
  model2.add(Dense(1))

  LR=0.0001
  opt = keras.optimizers.Adam(learning_rate=LR )
  model2.compile(optimizer=opt, loss=LOSS )

  C = []
  C.append( tf.keras.callbacks.EarlyStopping(monitor="val_loss",
            min_delta=0,
            patience=0,
            verbose=0,
            mode="auto",
            baseline=None,
            restore_best_weights=False,
            start_from_epoch=0,)
  )
  t ='trn'
  h = model2.fit(X[t], Y[t], validation_data=(X['val'], Y['val']), epochs=5000, verbose=0, callbacks=C)
  hist = h.history

  plt.figure()
  for kk in hist.keys():
    plt.plot( hist[kk], label=kk )
  plt.legend()
  plt.title(L)
  print( model2.summary() )
  return eval_model(model2, X, Y )


for suffix in [ '-', '-SC1', '-SC2' ]:
  for arc in ['', 'bi', 'cnn']:

    if 1:
      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', 'prcp', 'srad']
      mid =arc+f'lstm-{len(L)}vars' + suffix
      a,b,c= train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

    if 0:
      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', 'prcp']
      mid = arc+f'lstm-{len(L)}vars'
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', ]
      mid = arc+f'lstm-{len(L)}vars'
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

    if 1:
      L=['pm10.0_atm', 'srad', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'prcp', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'humidity', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

      L=['pm10.0_atm', 'temperature', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'pressure', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])
# Out:
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_195"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_280 (LSTM)             (None, 14, 50)            11400
#
#  lstm_281 (LSTM)             (None, 50)                20200
#
#  dense_195 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=187.014, RMSE=334.427, Spearman=0.047
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_196"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_282 (LSTM)             (None, 14, 50)            10600
#
#  lstm_283 (LSTM)             (None, 50)                20200
#
#  dense_196 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=15.752, RMSE=25.963, Spearman=0.201
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_197"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_284 (LSTM)             (None, 14, 50)            10600
#
#  lstm_285 (LSTM)             (None, 50)                20200
#
#  dense_197 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.687, RMSE=11.141, Spearman=0.320
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_198"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_286 (LSTM)             (None, 14, 50)            10600
#
#  lstm_287 (LSTM)             (None, 50)                20200
#
#  dense_198 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.621, RMSE=12.883, Spearman=0.054
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_199"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_288 (LSTM)             (None, 14, 50)            10600
#
#  lstm_289 (LSTM)             (None, 50)                20200
#
#  dense_199 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=6.283, RMSE=11.257, Spearman=0.050
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_200"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_290 (LSTM)             (None, 14, 50)            10600
#
#  lstm_291 (LSTM)             (None, 50)                20200
#
#  dense_200 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=5.367, RMSE=32.042, Spearman=0.240
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_201"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_140 (Bidirec  (None, 14, 100)           22800
#  tional)
#
#  bidirectional_141 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_201 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=70.551, RMSE=118.978, Spearman=-0.095
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_202"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_142 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_143 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_202 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=74.181, RMSE=93.870, Spearman=0.319
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_203"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_144 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_145 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_203 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.345, RMSE=9.689, Spearman=0.411
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_204"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_146 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_147 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_204 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=5.943, RMSE=10.444, Spearman=0.266
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_205"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_148 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_149 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_205 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.422, RMSE=12.734, Spearman=0.366
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_206"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_150 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_151 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_206 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=139.034, RMSE=200.456, Spearman=0.031
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_207"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_55 (Reshape)        (None, 14, 6)             0
#
#  conv1d_110 (Conv1D)         (None, 12, 14)            266
#
#  conv1d_111 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_55 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_55 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_55 (Flatten)        (None, 70)                0
#
#  dense_207 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=5.250, RMSE=12.230, Spearman=-0.265
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_208"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_56 (Reshape)        (None, 14, 2)             0
#
#  conv1d_112 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_113 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_56 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_56 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_56 (Flatten)        (None, 70)                0
#
#  dense_208 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.694, RMSE=13.781, Spearman=0.240
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_209"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_57 (Reshape)        (None, 14, 2)             0
#
#  conv1d_114 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_115 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_57 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_57 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_57 (Flatten)        (None, 70)                0
#
#  dense_209 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.278, RMSE=13.864, Spearman=0.207
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_210"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_58 (Reshape)        (None, 14, 2)             0
#
#  conv1d_116 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_117 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_58 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_58 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_58 (Flatten)        (None, 70)                0
#
#  dense_210 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.624, RMSE=12.231, Spearman=-0.117
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_211"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_59 (Reshape)        (None, 14, 2)             0
#
#  conv1d_118 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_119 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_59 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_59 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_59 (Flatten)        (None, 70)                0
#
#  dense_211 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.185, RMSE=11.629, Spearman=0.188
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_212"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_60 (Reshape)        (None, 14, 2)             0
#
#  conv1d_120 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_121 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_60 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_60 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_60 (Flatten)        (None, 70)                0
#
#  dense_212 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=5.896, RMSE=11.310, Spearman=0.100
# window size of 14 days 6 features
# Model: "sequential_213"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_304 (LSTM)             (None, 14, 50)            11400
#
#  lstm_305 (LSTM)             (None, 50)                20200
#
#  dense_213 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.570, RMSE=0.912, Spearman=0.293
# window size of 14 days 2 features
# Model: "sequential_214"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_306 (LSTM)             (None, 14, 50)            10600
#
#  lstm_307 (LSTM)             (None, 50)                20200
#
#  dense_214 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.544, RMSE=0.954, Spearman=0.307
# window size of 14 days 2 features
# Model: "sequential_215"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_308 (LSTM)             (None, 14, 50)            10600
#
#  lstm_309 (LSTM)             (None, 50)                20200
#
#  dense_215 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# <timed exec>:104: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
# None
# tst, MdAE=0.570, RMSE=0.938, Spearman=0.367
# window size of 14 days 2 features
# Model: "sequential_216"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_310 (LSTM)             (None, 14, 50)            10600
#
#  lstm_311 (LSTM)             (None, 50)                20200
#
#  dense_216 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.529, RMSE=0.938, Spearman=0.415
# window size of 14 days 2 features
# Model: "sequential_217"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_312 (LSTM)             (None, 14, 50)            10600
#
#  lstm_313 (LSTM)             (None, 50)                20200
#
#  dense_217 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.568, RMSE=0.957, Spearman=0.249
# window size of 14 days 2 features
# Model: "sequential_218"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_314 (LSTM)             (None, 14, 50)            10600
#
#  lstm_315 (LSTM)             (None, 50)                20200
#
#  dense_218 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.532, RMSE=0.926, Spearman=0.300
# window size of 14 days 6 features
# Model: "sequential_219"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_152 (Bidirec  (None, 14, 100)           22800
#  tional)
#
#  bidirectional_153 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_219 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.526, RMSE=0.930, Spearman=0.416
# window size of 14 days 2 features
# Model: "sequential_220"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_154 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_155 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_220 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.512, RMSE=0.936, Spearman=0.333
# window size of 14 days 2 features
# Model: "sequential_221"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_156 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_157 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_221 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.554, RMSE=0.920, Spearman=0.368
# window size of 14 days 2 features
# Model: "sequential_222"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_158 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_159 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_222 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.557, RMSE=0.940, Spearman=0.358
# window size of 14 days 2 features
# Model: "sequential_223"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_160 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_161 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_223 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.568, RMSE=0.937, Spearman=0.213
# window size of 14 days 2 features
# Model: "sequential_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_162 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_163 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_224 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.543, RMSE=0.946, Spearman=0.244
# window size of 14 days 6 features
# Model: "sequential_225"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_61 (Reshape)        (None, 14, 6)             0
#
#  conv1d_122 (Conv1D)         (None, 12, 14)            266
#
#  conv1d_123 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_61 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_61 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_61 (Flatten)        (None, 70)                0
#
#  dense_225 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.567, RMSE=0.971, Spearman=0.157
# window size of 14 days 2 features
# Model: "sequential_226"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_62 (Reshape)        (None, 14, 2)             0
#
#  conv1d_124 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_125 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_62 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_62 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_62 (Flatten)        (None, 70)                0
#
#  dense_226 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.431, RMSE=0.922, Spearman=0.312
# window size of 14 days 2 features
# Model: "sequential_227"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_63 (Reshape)        (None, 14, 2)             0
#
#  conv1d_126 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_127 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_63 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_63 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_63 (Flatten)        (None, 70)                0
#
#  dense_227 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.430, RMSE=0.991, Spearman=0.139
# window size of 14 days 2 features
# Model: "sequential_228"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_64 (Reshape)        (None, 14, 2)             0
#
#  conv1d_128 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_129 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_64 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_64 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_64 (Flatten)        (None, 70)                0
#
#  dense_228 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.519, RMSE=1.066, Spearman=0.069
# window size of 14 days 2 features
# Model: "sequential_229"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_65 (Reshape)        (None, 14, 2)             0
#
#  conv1d_130 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_131 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_65 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_65 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_65 (Flatten)        (None, 70)                0
#
#  dense_229 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.600, RMSE=1.132, Spearman=-0.326
# window size of 14 days 2 features
# Model: "sequential_230"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_66 (Reshape)        (None, 14, 2)             0
#
#  conv1d_132 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_133 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_66 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_66 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_66 (Flatten)        (None, 70)                0
#
#  dense_230 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.535, RMSE=1.121, Spearman=-0.321
# window size of 14 days 6 features
# Model: "sequential_231"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_328 (LSTM)             (None, 14, 50)            11400
#
#  lstm_329 (LSTM)             (None, 50)                20200
#
#  dense_231 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.097, RMSE=0.169, Spearman=-0.140
# window size of 14 days 2 features
# Model: "sequential_232"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_330 (LSTM)             (None, 14, 50)            10600
#
#  lstm_331 (LSTM)             (None, 50)                20200
#
#  dense_232 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.095, RMSE=0.159, Spearman=0.213
# window size of 14 days 2 features
# Model: "sequential_233"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_332 (LSTM)             (None, 14, 50)            10600
#
#  lstm_333 (LSTM)             (None, 50)                20200
#
#  dense_233 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.090, RMSE=0.156, Spearman=0.391
# window size of 14 days 2 features
# Model: "sequential_234"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_334 (LSTM)             (None, 14, 50)            10600
#
#  lstm_335 (LSTM)             (None, 50)                20200
#
#  dense_234 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# ...
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_164 (Bidirec  (None, 14, 100)           22800
#  tional)
#
#  bidirectional_165 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_237 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.107, RMSE=0.170, Spearman=-0.086
# window size of 14 days 2 features
# Model: "sequential_238"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_166 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_167 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_238 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.091, RMSE=0.166, Spearman=0.109
# window size of 14 days 2 features
# Model: "sequential_239"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_168 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_169 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_239 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.083, RMSE=0.150, Spearman=0.443
# window size of 14 days 2 features
# Model: "sequential_240"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_170 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_171 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_240 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.106, RMSE=0.162, Spearman=0.276
# window size of 14 days 2 features
# Model: "sequential_241"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_172 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_173 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_241 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.095, RMSE=0.159, Spearman=0.315
# window size of 14 days 2 features
# Model: "sequential_242"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_174 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_175 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_242 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.097, RMSE=0.159, Spearman=0.301
# window size of 14 days 6 features
# Model: "sequential_243"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_67 (Reshape)        (None, 14, 6)             0
#
#  conv1d_134 (Conv1D)         (None, 12, 14)            266
#
#  conv1d_135 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_67 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_67 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_67 (Flatten)        (None, 70)                0
#
#  dense_243 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.101, RMSE=0.201, Spearman=0.181
# window size of 14 days 2 features
# Model: "sequential_244"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_68 (Reshape)        (None, 14, 2)             0
#
#  conv1d_136 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_137 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_68 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_68 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_68 (Flatten)        (None, 70)                0
#
#  dense_244 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.085, RMSE=0.201, Spearman=-0.115
# window size of 14 days 2 features
# Model: "sequential_245"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_69 (Reshape)        (None, 14, 2)             0
#
#  conv1d_138 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_139 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_69 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_69 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_69 (Flatten)        (None, 70)                0
#
#  dense_245 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.068, RMSE=0.205, Spearman=-0.215
# window size of 14 days 2 features
# Model: "sequential_246"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_70 (Reshape)        (None, 14, 2)             0
#
#  conv1d_140 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_141 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_70 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_70 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_70 (Flatten)        (None, 70)                0
#
#  dense_246 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.050, RMSE=0.176, Spearman=0.232
# window size of 14 days 2 features
# Model: "sequential_247"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_71 (Reshape)        (None, 14, 2)             0
#
#  conv1d_142 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_143 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_71 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_71 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_71 (Flatten)        (None, 70)                0
#
#  dense_247 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.079, RMSE=0.161, Spearman=0.163
# window size of 14 days 2 features
# Model: "sequential_248"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_72 (Reshape)        (None, 14, 2)             0
#
#  conv1d_144 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_145 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_72 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_72 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_72 (Flatten)        (None, 70)                0
#
#  dense_248 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.090, RMSE=0.202, Spearman=0.006
# CPU times: user 7min 41s, sys: 4.99 s, total: 7min 46s
# Wall time: 7min 59s

# %%
LOSS
# Out:
# 'mean_absolute_error'

# %%
Res_DF.R2=Res_DF.R2.astype(float)
Res_DF.MdAE=Res_DF.MdAE.astype(float)
Res_DF.RMSE=Res_DF.RMSE.astype(float)

# %%
import plotly.express as px
px.bar( Res_DF.iloc[:24,:], y='MdAE', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="da9232fc-41fb-4f20-9c27-63a3e33d007a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da9232fc-41fb-4f20-9c27-63a3e33d007a")) {                    Plotly.newPlot(                        "da9232fc-41fb-4f20-9c27-63a3e33d007a",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eMdAE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bilstm-uni-","lstm-uni-","bilstm-uni-SC1","lstm-uni-SC1","bilstm-uni-SC2","lstm-uni-SC2","lstm-6vars-","lstm-srad-","lstm-prcp-","lstm-humidity-","lstm-temperature-","lstm-pressure-","bilstm-6vars-","bilstm-srad-","bilstm-prcp-","bilstm-humidity-","bilstm-temperature-","bilstm-pressure-","cnnlstm-6vars-","cnnlstm-srad-","cnnlstm-prcp-","cnnlstm-humidity-","cnnlstm-temperature-","cnnlstm-pressure-"],"xaxis":"x","y":[14.598400217049978,15.35849902004309,1.483672268812202,1.3221046413722144,0.29368492821946257,0.2898449063265286,334.4274503298584,25.96271236253963,11.140972772495664,12.883006833934425,11.256543288862467,32.04235667277362,118.97776597872235,93.86981976637807,9.689159507605922,10.443989971123775,12.734105155079018,200.45630762354975,12.230440316469318,13.781409368031136,13.863612970404867,12.231277313872996,11.628828807365718,11.31043222603446],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"# ...

# %%
px.bar( Res_DF.iloc[24:,:], y='MdAE', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e16113c4-c3aa-4b40-8d04-7dcfbb2c859c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e16113c4-c3aa-4b40-8d04-7dcfbb2c859c")) {                    Plotly.newPlot(                        "e16113c4-c3aa-4b40-8d04-7dcfbb2c859c",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eMdAE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["lstm-6vars-SC1","lstm-srad-SC1","lstm-prcp-SC1","lstm-humidity-SC1","lstm-temperature-SC1","lstm-pressure-SC1","bilstm-6vars-SC1","bilstm-srad-SC1","bilstm-prcp-SC1","bilstm-humidity-SC1","bilstm-temperature-SC1","bilstm-pressure-SC1","cnnlstm-6vars-SC1","cnnlstm-srad-SC1","cnnlstm-prcp-SC1","cnnlstm-humidity-SC1","cnnlstm-temperature-SC1","cnnlstm-pressure-SC1","lstm-6vars-SC2","lstm-srad-SC2","lstm-prcp-SC2","lstm-humidity-SC2","lstm-temperature-SC2","lstm-pressure-SC2","bilstm-6vars-SC2","bilstm-srad-SC2","bilstm-prcp-SC2","bilstm-humidity-SC2","bilstm-temperature-SC2","bilstm-pressure-SC2","cnnlstm-6vars-SC2","cnnlstm-srad-SC2","cnnlstm-prcp-SC2","cnnlstm-humidity-SC2","cnnlstm-temperature-SC2","cnnlstm-pressure-SC2"],"xaxis":"x","y":[0.9122898462465111,0.9541849058700943,0.9375353294170578,0.9380068735919775,0.9571430936161868,0.9263536649429681,0.929690290771887,0.9360860781008341,0.9198243611841437,0.9398717187344284,0.9370893172917992,0.9460845138843569,0.9713094416650556,0.9220372541863061,0.9906282390521199,1.0663519188348607,1.1321321131775004,1.12099335244096,0.16938793075782524,0.15942091407501913,0.1564393849143076,0.15682697509475288,0.16256232434347753,0.15675049736501326,0.16984737872365807,0.16640673789818158,0.14975768954724034,0.16170169966916081,0.15888592976448826,0.15874048531811163,0.20132215001211096,0.20054957481426325,0.2054928254194492,0.17628490948068656,0.16052043700210591,0.2024232003636573],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outl ...

# %%
px.bar( Res_DF, y='R2', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="340a27df-568e-4d0e-b3cd-61342af41e35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("340a27df-568e-4d0e-b3cd-61342af41e35")) {                    Plotly.newPlot(                        "340a27df-568e-4d0e-b3cd-61342af41e35",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eR2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bilstm-uni-","lstm-uni-","bilstm-uni-SC1","lstm-uni-SC1","bilstm-uni-SC2","lstm-uni-SC2","lstm-6vars-","lstm-srad-","lstm-prcp-","lstm-humidity-","lstm-temperature-","lstm-pressure-","bilstm-6vars-","bilstm-srad-","bilstm-prcp-","bilstm-humidity-","bilstm-temperature-","bilstm-pressure-","cnnlstm-6vars-","cnnlstm-srad-","cnnlstm-prcp-","cnnlstm-humidity-","cnnlstm-temperature-","cnnlstm-pressure-","lstm-6vars-SC1","lstm-srad-SC1","lstm-prcp-SC1","lstm-humidity-SC1","lstm-temperature-SC1","lstm-pressure-SC1","bilstm-6vars-SC1","bilstm-srad-SC1","bilstm-prcp-SC1","bilstm-humidity-SC1","bilstm-temperature-SC1","bilstm-pressure-SC1","cnnlstm-6vars-SC1","cnnlstm-srad-SC1","cnnlstm-prcp-SC1","cnnlstm-humidity-SC1","cnnlstm-temperature-SC1","cnnlstm-pressure-SC1","lstm-6vars-SC2","lstm-srad-SC2","lstm-prcp-SC2","lstm-humidity-SC2","lstm-temperature-SC2","lstm-pressure-SC2","bilstm-6vars-SC2","bilstm-srad-SC2","bilstm-prcp-SC2","bilstm-humidity-SC2","bilstm-temperature-SC2","bilstm-pressure-SC2","cnnlstm-6vars-SC2","cnnlstm-srad-SC2","cnnlstm-prcp-SC2","cnnlstm-humidity-SC2","cnnlstm-temperature-SC2","cnnlstm-pressure-SC2"],"xaxis":"x","y":[0.43716637946535397,0.3585883914779213,0.4042753656016376,0.3723851569747427,0.39155932546036903,0.3772607004679726,0.046999134823095215,0.20060255052018774,0.3200223554332495,0.05369841102570821,0.04974819265716459,0.2397403761643246,-0.0951165963076046,0.3185652007684639,0.4107777552617511,0.2663317144190846,0.3658992785891588,0.03076258570167001,-0.2651942402292244,0.2395092183209107,0.20712769521410662,-0.11690884243271282,0.18766437129890373,0.10045223548436417,0.2925430158592524,0.30683151208660125,0.36741096208495383,0.41465166101692275,0.24911281383825346,0.29974984031589186,0.4155299498217307,0.3327830731408922,0.36799482295235225,0.35809027823791184,0.21282380742639398,0.24416692399051526,0.15737908630632363,0.3119197596458297,0.13908140287282553,0.06905278633655385,-0.3264249836951549,-0.32112472582095863,-0.1399986804855562,0.21331304065321113,0.39080549559046046,0.3977879609637864,0.23855267439984504,0.3509626801489731,-0.08593313641442592,0.10866083642926791,0.4432106159448236,0.2762244653660039,0.31485474275611436,0.3007582768140505,0.1809983951457621,-0.11528060876376799,-0.21507336451839248,0.23186061320795087,0.16294338582278678,0.0058137723870862875],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %%
px.bar( Res_DF, y='RMSE', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bda48208-0f24-4258-8adb-6b3d57155855" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bda48208-0f24-4258-8adb-6b3d57155855")) {                    Plotly.newPlot(                        "bda48208-0f24-4258-8adb-6b3d57155855",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eRMSE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bilstm-uni-","lstm-uni-","bilstm-uni-SC1","lstm-uni-SC1","bilstm-uni-SC2","lstm-uni-SC2","lstm-6vars-","lstm-srad-","lstm-prcp-","lstm-humidity-","lstm-temperature-","lstm-pressure-","bilstm-6vars-","bilstm-srad-","bilstm-prcp-","bilstm-humidity-","bilstm-temperature-","bilstm-pressure-","cnnlstm-6vars-","cnnlstm-srad-","cnnlstm-prcp-","cnnlstm-humidity-","cnnlstm-temperature-","cnnlstm-pressure-","lstm-6vars-SC1","lstm-srad-SC1","lstm-prcp-SC1","lstm-humidity-SC1","lstm-temperature-SC1","lstm-pressure-SC1","bilstm-6vars-SC1","bilstm-srad-SC1","bilstm-prcp-SC1","bilstm-humidity-SC1","bilstm-temperature-SC1","bilstm-pressure-SC1","cnnlstm-6vars-SC1","cnnlstm-srad-SC1","cnnlstm-prcp-SC1","cnnlstm-humidity-SC1","cnnlstm-temperature-SC1","cnnlstm-pressure-SC1","lstm-6vars-SC2","lstm-srad-SC2","lstm-prcp-SC2","lstm-humidity-SC2","lstm-temperature-SC2","lstm-pressure-SC2","bilstm-6vars-SC2","bilstm-srad-SC2","bilstm-prcp-SC2","bilstm-humidity-SC2","bilstm-temperature-SC2","bilstm-pressure-SC2","cnnlstm-6vars-SC2","cnnlstm-srad-SC2","cnnlstm-prcp-SC2","cnnlstm-humidity-SC2","cnnlstm-temperature-SC2","cnnlstm-pressure-SC2"],"xaxis":"x","y":[5.254708492279053,5.534383603096009,0.5701280960393378,0.5453065318320063,0.12468282193059682,0.12122208986971672,187.01373950195313,15.751586387634278,3.6873453292846676,4.620876083374023,6.283448257446289,5.36691143321991,70.55063403320312,74.18144091796876,3.3449056892395017,5.942706367492676,4.421632995605469,139.03431372070312,5.249854179382324,3.6942141008377076,4.278175947189331,4.623994716644287,4.184911251068115,5.8955036125183105,0.5698120403215001,0.543597244909423,0.5698562538921427,0.5290568331496456,0.5675236149760791,0.5321025564405032,0.5258883710960036,0.5116606136308303,0.5540496370990996,0.5567162374745348,0.5676289464849101,0.5431451615279661,0.5666260166578129,0.4309502234986873,0.42954125197440174,0.5191617357360988,0.6002398535543974,0.5353264110910564,0.09676962667850712,0.0953608780381402,0.08977718384089396,0.10180913680588735,0.09246312451978969,0.09625206055288169,0.1066783025142869,0.09149804538691506,0.08294633326113013,0.10623170149312319,0.0949118589227264,0.09655016048534497,0.10071165568504994,0.08539846845925483,0.06827982462916335,0.0500122412216229,0.07887413807642304,0.09041759303467814],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %%
def compare( met_name='MdAE'  ):
  plt.figure( figsize=(20,3))
  M = Res_DF.shape[0]
  thickness = 4
  for i,r in enumerate( Res_DF.iterrows() ):
    k = r[1]['setting']
    m = r[1][ met_name ]
    n=len(m)
    q=365//3
    a=np.arange( 0, q*n, q )
    plt.bar( a+i*thickness, m, thickness, label = k )
  plt.legend()
  plt.title( f'{met_name} of test set for each method compared' )

#compare()

# %% [markdown]
# ## Performance measures achieved by different model-variable combinations

# %%
Res_DF.head(1000)
# Out:
#                     setting                     R2                 RMSE  \
# 0               bilstm-uni-    0.43716637946535397    5.254708492279053
# 1                 lstm-uni-     0.3585883914779213    5.534383603096009
# 2            bilstm-uni-SC1     0.4042753656016376   0.5701280960393378
# 3              lstm-uni-SC1     0.3723851569747427   0.5453065318320063
# 4            bilstm-uni-SC2    0.39155932546036903  0.12468282193059682
# 5              lstm-uni-SC2     0.3772607004679726  0.12122208986971672
# 6               lstm-6vars-   0.046999134823095215   187.01373950195313
# 7                lstm-srad-    0.20060255052018774   15.751586387634278
# 8                lstm-prcp-     0.3200223554332495   3.6873453292846676
# 9            lstm-humidity-    0.05369841102570821    4.620876083374023
# 10        lstm-temperature-    0.04974819265716459    6.283448257446289
# 11           lstm-pressure-     0.2397403761643246     5.36691143321991
# 12            bilstm-6vars-    -0.0951165963076046    70.55063403320312
# 13             bilstm-srad-     0.3185652007684639    74.18144091796876
# 14             bilstm-prcp-     0.4107777552617511   3.3449056892395017
# 15         bilstm-humidity-     0.2663317144190846    5.942706367492676
# 16      bilstm-temperature-     0.3658992785891588    4.421632995605469
# 17         bilstm-pressure-    0.03076258570167001   139.03431372070312
# 18           cnnlstm-6vars-    -0.2651942402292244    5.249854179382324
# 19            cnnlstm-srad-     0.2395092183209107   3.6942141008377076
# 20            cnnlstm-prcp-    0.20712769521410662    4.278175947189331
# 21        cnnlstm-humidity-   -0.11690884243271282    4.623994716644287
# 22     cnnlstm-temperature-    0.18766437129890373    4.184911251068115
# 23        cnnlstm-pressure-    0.10045223548436417   5.8955036125183105
# 24           lstm-6vars-SC1     0.2925430158592524   0.5698120403215001
# 25            lstm-srad-SC1    0.30683151208660125    0.543597244909423
# 26            lstm-prcp-SC1    0.36741096208495383   0.5698562538921427
# 27        lstm-humidity-SC1    0.41465166101692275   0.5290568331496456
# 28     lstm-temperature-SC1    0.24911281383825346   0.5675236149760791
# 29        lstm-pressure-SC1    0.29974984031589186   0.5321025564405032
# 30         bilstm-6vars-SC1     0.4155299498217307   0.5258883710960036
# 31          bilstm-srad-SC1     0.3327830731408922   0.5116606136308303
# 32          bilstm-prcp-SC1    0.36799482295235225   0.5540496370990996
# 33      bilstm-humidity-SC1    0.35809027823791184   0.5567162374745348
# 34   bilstm-temperature-SC1    0.21282380742639398   0.5676289464849101
# 35      bilstm-pressure-SC1    0.24416692399051526   0.5431451615279661
# 36        cnnlstm-6vars-SC1    0.15737908630632363   0.5666260166578129
# 37         cnnlstm-srad-SC1     0.3119197596458297   0.4309502234986873
# 38         cnnlstm-prcp-SC1    0.13908140287282553  0.42954125197440174
# 39     cnnlstm-humidity-SC1    0.06905278633655385   0.5191617357360988
# 40  cnnlstm-temperature-SC1    -0.3264249836951549   0.6002398535543974
# 41     cnnlstm-pressure-SC1   -0.32112472582095863   0.5353264110910564
# 42           lstm-6vars-SC2    -0.1399986804855562  0.09676962667850712
# 43            lstm-srad-SC2    0.21331304065321113   0.0953608780381402
# 44            lstm-prcp-SC2    0.39080549559046046  0.08977718384089396
# 45        lstm-humidity-SC2     0.3977879609637864  0.10180913680588735
# 46     lstm-temperature-SC2    0.23855267439984504  0.09246312451978969
# 47        lstm-pressure-SC2     0.3509626801489731  0.09625206055288169
# 48         bilstm-6vars-SC2   -0.08593313641442592   0.1066783025142869
# 49          bilstm-srad-SC2    0.10866083642926791  0.09149804538691506
# 50          bilstm-prcp-SC2     0.4432106159448236  0.08294633326113013
# 51      bilstm-humidity-SC2     0.2762244653660039  0.10623170149312319
# 52   bilstm-temperature-SC2    0.31485474275611436   0.0949118589227264
# 53      bilstm-pressure-SC2     0.3007582768140505  0.09655016048534497
# 54        cnnlstm-6vars-SC2     0.1809983951457621  0.10071165568504994
# 55         cnnlstm-srad-SC2   -0.11528060876376799  0.08539846845925483
# 56         cnnlstm-prcp-SC2   -0.21507336451839248  0.06827982462916335
# 57     cnnlstm-humidity-SC2    0.23186061320795087   0.0500122412216229
# 58  cnnlstm-temperature-SC2    0.16294338582278678  0.07887413807642304
# 59     cnnlstm-pressure-SC2  0.0058137723870862875  0.09041759303467814
#
#                    MdAE
# 0    14.598400217049978
# 1     15.35849902004309
# 2     1.483672268812202
# 3    1.3221046413722144
# 4   0.29368492821946257
# 5    0.2898449063265286
# 6     334.4274503298584
# 7     25.96271236253963
# 8    11.140972772495664
# 9    12.883006833934425
# 10   11.256543288862467
# 11    32.04235667277362
# 12   118.97776597872235
# 13    93.86981976637807
# 14    9.689159507605922
# 15   10.443989971123775
# 16   12.734105155079018
# 17   200.45630762354975
# 18   12.230440316469318
# 19   13.781409368031136
# 20   13.863612970404867
# 21   12.231277313872996
# 22   11.628828807365718
# 23    11.31043222603446
# 24   0.9122898462465111
# 25   0.9541849058700943
# 26   0.9375353294170578
# 27   0.9380068735919775
# 28   0.9571430936161868
# 29   0.9263536649429681
# 30    0.929690290771887
# 31   0.9360860781008341
# 32   0.9198243611841437
# 33   0.9398717187344284
# 34   0.9370893172917992
# 35   0.9460845138843569
# 36   0.9713094416650556
# 37   0.9220372541863061
# 38   0.9906282390521199
# 39   1.0663519188348607
# 40   1.1321321131775004
# 41     1.12099335244096
# 42  0.16938793075782524
# 43  0.15942091407501913
# 44   0.1564393849143076
# 45  0.15682697509475288
# 46  0.16256232434347753
# 47  0.15675049736501326
# 48  0.16984737872365807
# 49  0.16640673789818158
# 50  0.14975768954724034
# 51  0.16170169966916081
# 52  0.15888592976448826
# 53  0.15874048531811163
# 54  0.20132215001211096
# 55  0.20054957481426325
# 56   0.2054928254194492
# 57  0.17628490948068656
# 58  0.16052043700210591
# 59   0.2024232003636573
