# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/ccai2023/blob/main/PA_mean_squared_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Administrative setup
#
# - Execute code below to mount drive, install packages, and download resources.
#
# - Click on these buttons when the 2 pop-up windows show up:
#
# <img src="https://raw.githubusercontent.com/lisatwyw/CS4SocialGood/main/ccai/Mount.png" width="500"/>

# %%
# mount drive for permanent storage

import os, sys
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

try:
  # !mkdir /content/drive/MyDrive/purple_air
  # !mkdir /content/drive/MyDrive/purple_air/packages
except:
  pass

os.chdir('/content/drive/MyDrive/purple_air/')
nb_path = 'mypackages'

try:
  # create symbolic path
  os.symlink('/content/drive/MyDrive/purple_air/packages', nb_path)

  # install once to symbolic path
  # !pip install --target=$nb_path lale
  # !pip install --target=$nb_path daymetpy
  # !pip install --target=$nb_path geomdl
  #!pip install --target=$nb_path -U fastapi python-multipart uvicorn kaleido
  # !pip install --target=$nb_path -U plotly
except:
  pass

sys.path.insert(0, '/content/drive/MyDrive/purple_air/')

# !ls /content/drive/MyDrive/purple_air/
# Out:
# Mounted at /content/drive
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# mkdir: cannot create directory ‘/content/drive/MyDrive/purple_air’: File exists
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# mkdir: cannot create directory ‘/content/drive/MyDrive/purple_air/packages’: File exists
# 'Copy of PA_Oakland_2012_daily.csv'   PA_data_for_modeling_2017.csv
# 'Copy of PA_Oakland_2013_daily.csv'   PA_data_for_modeling_2018.csv
# 'Copy of PA_Oakland_2014_daily.csv'   PA_data_for_modeling_2019.csv
# 'Copy of PA_Oakland_2015_daily.csv'   PA_data_for_modeling_2020.csv
# 'Copy of PA_Oakland_2016_daily.csv'   PA_data_for_modeling_2021.csv
# 'Copy of PA_Oakland_2017_daily.csv'   PA_data_for_modeling_2022.csv
# 'Copy of PA_Oakland_2018_daily.csv'   PA_Oakland_2012_daily.csv
# 'Copy of PA_Oakland_2019_daily.csv'   PA_Oakland_2013_daily.csv
# 'Copy of PA_Oakland_2020_daily.csv'   PA_Oakland_2014_daily.csv
# 'Copy of PA_Oakland_2021_daily.csv'   PA_Oakland_2015_daily.csv
#  Lat_long_PA_sensors_full.csv	      PA_Oakland_2016_daily.csv
#  model.py			      PA_Oakland_2017_daily.csv
#  mypackages			      PA_Oakland_2018_daily.csv
#  Oakland_daily_daymet_data_2017.csv   PA_Oakland_2019_daily.csv
#  Oakland_daily_daymet_data_2018.csv   PA_Oakland_2020_daily.csv
#  Oakland_daily_daymet_data_2019.csv   PA_Oakland_2021_daily.csv
#  Oakland_daily_daymet_data_2020.csv   __pycache__
#  Oakland_daily_daymet_data_2021.csv   visualization-3.py
#  packages

# %% [markdown]
# ## Check for the precomputed files...

# %% [markdown]
# ```
# Collecting daymetpy
#   Downloading daymetpy-1.0.0.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: daymetpy
#   Building wheel for daymetpy (setup.py) ... done
#   Created wheel for daymetpy: filename=daymetpy-1.0.0-py3-none-any.whl size=4094 sha256=02cba4ef9e6a078a65eae7b80e803da850cb9a51ee06f8d896a974e9ad6c5fca
#   Stored in directory: /root/.cache/pip/wheels/56/d2/10/a37e259b28ccac8537185688acfb45913df0b826d5ad3962d7
# Successfully built daymetpy
# Installing collected packages: daymetpy
# Successfully installed daymetpy-1.0.0
#
#
# Collecting geomdl
#   Downloading geomdl-5.3.1-py2.py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: geomdl
# Successfully installed geomdl-5.3.1
#
#
#
# Collecting fastapi
#   Using cached fastapi-0.104.0-py3-none-any.whl (92 kB)
# Collecting python-multipart
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# Collecting uvicorn
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting kaleido
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Collecting anyio<4.0.0,>=3.7.1 (from fastapi)
#   Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi)
#   Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi)
#   Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting click>=7.0 (from uvicorn)
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting h11>=0.8 (from uvicorn)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting idna>=2.8 (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio>=1.1 (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached pydantic_core-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Installing collected packages: kaleido, typing-extensions, sniffio, python-multipart, idna, h11, exceptiongroup, click, annotated-types, uvicorn, pydantic-core, anyio, starlette, pydantic, fastapi
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed annotated-types-0.6.0 anyio-3.7.1 click-8.1.7 exceptiongroup-1.1.3 fastapi-0.104.0 h11-0.14.0 idna-3.4 kaleido-0.2.1 pydantic-2.4.2 pydantic-core-2.10.1 python-multipart-0.0.6 sniffio-1.3.0 starlette-0.27.0 typing-extensions-4.8.0 uvicorn-0.23.2
#
# ```

# %%
import requests
import pandas as pd # circular imports?

from datetime import datetime
import time
import json
import io
from io import StringIO
import geopandas
import matplotlib.pyplot as plt
from matplotlib import cm

import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import MarkerCluster, BeautifyIcon
import branca

# Import the daymetpy package
# import daymetpy

# Import packages for multiprocessing
import itertools
import multiprocessing as mp
from multiprocessing.pool import ThreadPool

from shapely.geometry import Point, Polygon

import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn' # You can turn off these warnings if you know what you are doing by using
import polars as pol

import math
import numpy as np

# %% [markdown]
# ## 2a. Steps to download PurpleAir
#
# 1. Visit [this page](https://develop.purpleair.com/keys)
# 2. Click "Add" button (top left)
# 3. Click "Add" button (bottom right)
#
# ![image](https://global.discourse-cdn.com/business7/uploads/purpleair/optimized/2X/d/d47145bfc7631a5b48b6aa006c320562a04358ac_2_690x318.png)

# %%
# !curl -X GET "https://api.purpleair.com/v1/keys" -H "X-API-Key: xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxx"
# Out:
# {
#   "api_version" : "V1.0.11-0.0.49",
#   "time_stamp" : 1697775957,
#   "error" : "ApiKeyInvalidError",
#   "description" : "The provided api_key was not valid."
# }

# %%
# !curl -X GET "https://api.purpleair.com/v1/keys"
# Out:
# {
#   "api_version" : "V1.0.11-0.0.49",
#   "time_stamp" : 1697775957,
#   "error" : "ApiKeyMissingError",
#   "description" : "No API key was found in the request."
# }

# %% [markdown]
# # 2b. Read in the pre-downloaded and merged dataframe

# %%
YEAR = 2022

pa_df = pd.read_csv(f'PA_data_for_modeling_{YEAR}.csv')
sensor_list1 = pa_df.drop_duplicates(subset=['latitude', 'longitude'], keep='last') # latest snapshot
sensor_list = pa_df.drop_duplicates(subset=['latitude', 'longitude'], keep='first') # earliest snapshot

key_to_predict ='pm10.0_atm'
max_value = pa_df[key_to_predict ].max()
min_value = pa_df[key_to_predict ].min()
print( min_value, max_value )
nlevels = 5 # color levels
# define colours for each level
ss_colors=['#ff00ff', '#ff40bf', '#ff807f', '#ffc03f', '#ffff00']

mx, mn = np.int64(max_value) -1,  np.int64(min_value)
sensor_list.head()
# Out:
# 0.0 3356.8825
#       Unnamed: 0  sensor                      name   latitude  longitude  \
# 0              0   13997                   Hilltop  37.834310 -122.22653
# 365          365   15645  Redwood Heights, Oakland  37.801030 -122.18855
# 730          730   17927              West Oakland  37.817640 -122.27246
# 1095        1095   18997         Head-Royce School  37.808174 -122.20474
# 1460        1460   19273                Sims Drive  37.821156 -122.20937
#
#        Datestamp   humidity  temperature     pressure  pm10.0_atm  \
# 0     2022-01-01  45.919000    52.233000   996.909000      3.8495
# 365   2022-01-01  43.398000    55.553000  1003.290000      3.7900
# 730   2022-01-01  63.971281    64.467907   998.648163      8.9030
# 1095  2022-01-01  48.510000    52.771000  1005.613000      4.1550
# 1460  2022-01-01  48.233000    51.056000   997.452000      2.5380
#
#       pm10.0_cf_1  prcp    srad
# 0          3.9565   0.0  219.00
# 365        3.7900   0.0  227.48
# 730        8.9205   0.0  216.46
# 1095       4.1550   0.0  224.64
# 1460       2.5385   0.0  220.62

# %%
from folium.features import DivIcon

def draw( sensor_list, ss_filtered_legend_index, annotate=True, description='first' ):
  # create nao
  map = folium.Map(location=[sensor_list['latitude'].mean(), sensor_list['longitude'].mean()], zoom_start=13, control_scale=True)

  # add annotations on the map

  # - for each sensor location, add diamond whose size represents measured value
  for index, row in sensor_list.iterrows():
      local_deformation = math.cos(row['latitude'] * math.pi / 180)
      size = row[ key_to_predict ]*60/max_value * local_deformation

      folium.features.RegularPolygonMarker(
                  location =[row['latitude'], row['longitude']],
                  radius   = size,
                  fill_color=ss_colors[row['color_labels']],
                  color = ss_colors[row['color_labels']],
      ).add_to(map)

      if annotate:
        folium.map.Marker( [row['latitude'], row['longitude']],
                  icon=DivIcon(
                  icon_size=(250,36),
                  icon_anchor=(0,0),
                  html='<div style="font-size: 4pt">%s</div>'% row['sensor'] )
        ).add_to(map)

  sw = sensor_list[['latitude', 'longitude']].min().values.tolist()
  ne = sensor_list[['latitude', 'longitude']].max().values.tolist()

  # # Get maximum quantity of emissions from stationary source
  colormap = branca.colormap.LinearColormap(ss_colors,
                                            index=ss_filtered_legend_index[1:],
                                            vmin=0, vmax=max_value,
                                            caption= f'{key_to_predict} measured on {description} day' )
  colormap.add_to(map)
  if 1:
    svg_style = '<style>svg#legend {font-size: 14px; background-color: white;}</style>'
    map.get_root().header.add_child(folium.Element(svg_style))

  bw = 0.005 # width of bounding box
  map.fit_bounds([ [sw[0]-bw,sw[1]-bw], [ne[0]+bw, ne[1]+bw] ] )
  return map


sensor_list['color_labels'] = pd.cut(sensor_list[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[0]
ss_filtered_legend_index = pd.cut(sensor_list[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[1]
map0 = draw( sensor_list, ss_filtered_legend_index )


sensor_list1['color_labels'] = pd.cut(sensor_list1[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[0]
ss_filtered_legend_index1 = pd.cut(sensor_list1[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[1]
map1 = draw( sensor_list1, ss_filtered_legend_index1, True, 'last' )

from IPython.core.display import display, HTML
#from IPython.display import IFrame

htmlmap = HTML('<iframe srcdoc="{}" style="float:left; width: {}px; height: {}px; display:inline-block; width: 50%; margin: 0 auto; border: 0px solid black"></iframe>'
           '<iframe srcdoc="{}" style="float:right; width: {}px; height: {}px; display:inline-block; width: 50%; margin: 0 auto; border: 0px solid black"></iframe>'
           .format(map0.get_root().render().replace('"', '&quot;'),100, 300,
                   map1.get_root().render().replace('"', '&quot;'),100, 300))
display(htmlmap)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe srcdoc="<!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#     <style>svg#legend {font-size: 14px; background-color: white;}</style>
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_b8b64b357eaf035360b97018d7c76269 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;></script>
# </head>
# <body>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_b8b64b357eaf035360b97018d7c76269&quot; ></div>
#
# </body>
# <script>
#
#
#             var map_b8b64b357eaf035360b97018d7c76269 = L.map(
#                 &quot;map_b8b64b357eaf035360b97018d7c76269&quot;,
#                 {
#                     center: [37.79476809189189, -122.21982534054055],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#
#
#
#             var tile_layer_9cedb280d1eb0d36d4414e103be74b2a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var regular_polygon_marker_9ad18ef98ea37739f341d0655ed7fbf4 = new L.RegularPolygonMarker(
#                 [37.83431, -122.22653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.05434128221704802, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var marker_913549dbc336d1aa33ae414a72f1a76e = L.marker(
#                 [37.83431, -122.22653],
#                 {}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var div_icon_832afcf3857e2d89f99c720d738ff0bb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e13997\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_913549dbc336d1aa33ae414a72f1a76e.setIcon(div_icon_832afcf3857e2d89f99c720d738ff0bb);
#
#
#             var regular_polygon_marker_7ee2f8e5473c1a3757fb4912090cea44 = new L.RegularPolygonMarker(
#                 [37.80103, -122.18855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0535254791476388, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var marker_586b54fd224db216ff726f5d78327f5e = L.marker(
#                 [37.80103, -122.18855],
#                 {}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var div_icon_824bf724166d0b1cd69280eafb03e118 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e15645\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_586b54fd224db216ff726f5d78327f5e.setIcon(div_icon_824bf724166d0b1cd69280eafb03e118);
#
#
#             var regular_polygon_marker_87e1635866386424576b053fc74329ba = new L.RegularPolygonMarker(
#                 [37.81764, -122.27246],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12570716581573485, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var marker_60fb298d80f5fffe4ed553e0db087c58 = L.marker(
#                 [37.81764, -122.27246],
#                 {}
#             ).addTo(map_b8b64b357eaf035360b97018d7c76269);
#
#
#             var div_icon_c3cd1a5118596661b48c0da5f6741580 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e17927\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_60fb298d80f5fffe4ed553e0db087c58.setIcon(div_icon_c3cd1a5118596661b48c0da5f6741580);

# %% [markdown]
# # Naive surface-fitting

# %%
# %matplotlib inline

MAP_WIDTH, MAP_HEIGHT = 300, 100
x = ((MAP_WIDTH/360.0) * (180 + sensor_list.latitude.values ));   # translate x and rescaled
y = ((MAP_HEIGHT/180.0) * (90 - sensor_list.longitude.values ));  # reflect y and rescaled

plt.scatter( x, y, color='red' )
plt.figure()
plt.scatter( sensor_list.latitude.values, sensor_list.longitude.values )

# %%
# %matplotlib inline

import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# test function
def function(data, p00, p10, p01, p20, p11, p02, p21, p12, p03 ):
    x = data[0]
    y = data[1]
    d = p00 + p10*x + p01*y + p20*(x**2) + p11*x*y + p02*(y**2) + p21*(x**2)*y + p12*x*(y**2) + p03*(y**3)
    return d

#x_data = sensor_list.latitude
#y_data = sensor_list.longitude
x_data = ((MAP_WIDTH/360.0) * (180 + sensor_list.latitude));
y_data = ((MAP_HEIGHT/180.0) * (90 - sensor_list.longitude));
z_data = sensor_list[ key_to_predict ]

# get fit parameters from scipy curve fit
parameters, covariance = curve_fit(function, [x_data, y_data], z_data)

# create surface function model
# setup data points for calculating surface model
model_x_data = np.linspace(min(x_data), max(x_data), 30)
model_y_data = np.linspace(min(y_data), max(y_data), 30)

# create coordinate arrays for vectorized evaluations
X, Y = np.meshgrid(model_x_data, model_y_data)

# calculate Z coordinate array
Z = function(np.array([X, Y]), *parameters)

# setup figure object
fig = plt.figure()
ax = plt.axes(projection ="3d")
ax.scatter3D(x_data, y_data, z_data, color = "blue")
ax.scatter3D(X, Y, Z, color = "red")

# %%
parameters
# Out:
# array([-2.39207223e+06, -4.15825446e+02,  1.26940571e+04,  2.11093395e+02,
#        -3.45833002e+02,  3.31416195e+02, -5.22962143e+01,  1.58527078e+02,
#        -1.22053456e+02])

# %%
Z_est = function(np.array([x_data, y_data]), *parameters)
rmse = np.sqrt( np.mean( (Z_est - z_data)**2 ))
rmse
# Out:
# 267.7010773028493

# %% [markdown]
# ## Distances between pairs of sensors

# %%
from sklearn.metrics.pairwise import euclidean_distances
import seaborn as sns

n=sensor_list.shape[0]
dist = np.zeros( (n,n) )
for a,(lat1,long1) in enumerate( zip( list(sensor_list.latitude.values), list(sensor_list.longitude.values) ) ):
    for b,(lat2,long2) in enumerate( zip( list(sensor_list.latitude.values), list(sensor_list.longitude.values) ) ):
      if (a != b):
        # ACOS( SIN(lat1)*SIN(lat2) + COS(lat1)*COS(lat2)*COS(lon2-lon1) ) * 6371000
        d=np.arccos( np.sin(lat1)*np.sin(lat2) + np.cos( lat1)*np.cos(lat2) *np.cos(long1-long2) ) * 6371000
        dist[a,b]= dist[b,a] = d

sns.heatmap( dist )
#plt.imshow(dist)
# Out:
# <Axes: >

# %%
j=1

s1=sensor_list['sensor'].values[j]
q = np.argmax( dist[:, j ] )
s2=sensor_list['sensor'].values[q]

# %% [markdown]
# # Starter's benchmark
#
#
# Goal of this section is to setup a forecast formulation:
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i )$
#
# where $y_i^{t+1}$ is the measured PM10 for sensor $i$ at time $t$+1 given measurements made from timepoints 1 to $t$
#
#
# At the end of this section, we compare performances of different RNN architectures and examine the effects of inclusions of other time-series, e.g.
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i , \text{radiation}_i^{1:t} )$
#
# ...
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i , \text{radiation}_i^{1:t}, \text{temperature}_i^{1:t}, \text{pressure}_i^{1:t} )$

# %%
grps=pa_df.groupby( by='sensor')
grps.groups.keys()
# Out:
# dict_keys([13997, 15645, 17927, 18997, 19273, 19275, 19299, 19471, 19509, 19664, 20747, 20951, 21285, 22067, 22423, 27135, 34923, 36111, 36153, 37149, 37311, 37491, 37693, 38193, 38613, 38683, 38849, 40059, 41503, 46127, 46331, 50377, 52995, 53219, 53917, 55183, 55811, 55817, 55915, 55961, 55991, 56071, 56281, 59649, 59737, 59921, 60025, 60167, 60333, 60653, 60711, 61359, 61423, 61621, 62303, 62363, 63257, 63509, 63553, 63605, 63849, 63981, 64063, 64429, 64953, 65225, 65251, 65375, 65787, 65849, 65867, 66155, 67261, 67265, 67325, 67359, 67787, 67801, 67943, 67951, 68657, 68711, 68943, 69121, 69131, 69235, 69323, 69587, 69851, 69919, 70015, 70109, 70117, 70663, 70669, 71453, 71461, 71797, 72609, 73149, 73231, 73565, 74161, 74481, 75223, 76071, 76125, 77149, 77397, 77703, 77887, 78475, 80799, 80833, 81017, 81245, 82055, 82105, 83191, 83449, 83737, 84197, 84395, 84721, 84923, 85165, 85357, 85571, 85591, 85835, 87307, 92097, 93855, 95573, 96173, 96309, 97215, 98099, 101515, 103290, 103850, 103852, 105206, 106120, 107652, 108628, 109324, 110306, 110480, 110985, 111530, 111686, 112008, 112308, 112478, 112488, 113222, 113346, 113414, 113608, 114189, 115633, 116023, 116097, 116153, 116229, 116431, 117015, 117935, 117971, 118973, 118977, 119005, 119485, 119607, 119647, 120669, 121107, 121427, 122013, 122061, 126137, 126591, 131817, 137014])

# %%
# sensor lists are identical during this year if the intersection is empty
np.setdiff1d( sensor_list.sensor, sensor_list1.sensor )
# Out:
# array([], dtype=int64)

# %%
if 0:
  s1,s2=13997, 15645 # neighbouring sensors
  s1,s2=87307, 82105 # neighbouring sensors
  s1,s2=87307, 17927 # distant neighbours
  s1,s2=87307, 17927 # distant neighbours

# %%
key_to_predict = 'pm10.0_atm'

print( pa_df.loc[ grps.groups[s1] ][ ['latitude','longitude'] ].head(1) )
print( pa_df.loc[ grps.groups[s2] ][ ['latitude','longitude'] ].head(1) )

xx = np.arange(365)

plt.plot( xx, pa_df.loc[grps.groups[s1]][ key_to_predict ], color='blue')
plt.plot( xx, pa_df.loc[grps.groups[s2]][ key_to_predict ], color='cyan')
# Out:
#      latitude  longitude
# 365  37.80103 -122.18855
#         latitude  longitude
# 60590  37.787052 -122.30934

# %% [markdown]
# # 4a. Develop and evaluate univariate forecast models

# %% [markdown]
# ## Example experimenal setup
#
# | | | |
# | :-- | :-- | :-- |
# | Sensor 1 | TRN | VAL |
# | Sensor 2 | TST  |

# %%
trn = pa_df.loc[grps.groups[s1]].iloc[0:365//3,:]
val = pa_df.loc[grps.groups[s1]].iloc[(365//3):(2*365//3),: ]

trn.head(2)
# Out:
#      Unnamed: 0  sensor                      name  latitude  longitude  \
# 365         365   15645  Redwood Heights, Oakland  37.80103 -122.18855
# 366         366   15645  Redwood Heights, Oakland  37.80103 -122.18855
#
#       Datestamp  humidity  temperature  pressure  pm10.0_atm  pm10.0_cf_1  \
# 365  2022-01-01    43.398       55.553  1003.290       3.790        3.790
# 366  2022-01-02    40.700       55.214  1008.911       6.218        6.218
#
#      prcp    srad
# 365   0.0  227.48
# 366   0.0  259.95

# %%
trn.tail(2)
# Out:
#      Unnamed: 0  sensor                      name  latitude  longitude  \
# 484         484   15645  Redwood Heights, Oakland  37.80103 -122.18855
# 485         485   15645  Redwood Heights, Oakland  37.80103 -122.18855
#
#       Datestamp  humidity  temperature  pressure  pm10.0_atm  pm10.0_cf_1  \
# 484  2022-04-30    42.798       69.854  1001.959       4.762        4.762
# 485  2022-05-01    45.395       66.350   998.348       5.561        5.561
#
#      prcp    srad
# 484   0.0  441.63
# 485   0.0  511.58

# %%
# %%time

# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

import tensorflow as tf

from numpy import array
import keras
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, GRU
from keras.layers import Dense

from keras.layers import Bidirectional
import scipy
from sklearn.preprocessing import StandardScaler

def eval_model(model, X, Y ):
  m1,m2,m3=[],[],[]
  t='tst'
  yhat = model.predict(X[t], verbose=0)
  spearman_stats=scipy.stats.spearmanr( Y[t], yhat.squeeze(), )
  delta = np.abs(Y[t]- yhat.squeeze() )
  MdAE = np.median( delta )
  RMSE = np.sqrt( np.mean( delta**2 ))
  print( f'{t}, MdAE={MdAE:.3f}, RMSE={RMSE:.3f}, Spearman={spearman_stats[0]:.3f}' )
  if len(m1)==0:
    return spearman_stats[0], MdAE, RMSE
  else:
    m1.append( spearman_stats[0] )
    m2.append( MdAE )
    m3.append( RMSE )
    return np.array(m1), np.array(m2), np.array(m3)

def train_eval_univariate(s1, s2, mid = 'lstm-uni', k = 'pm10.0_atm' ):

  # split a univariate sequence into samples
  def split_sequence(sequence, n_days, S=None):

    sequence=sequence.reshape(-1,1) # for rescaling 1D

    if suffix == '-':
      S = None
    else:
      if S is None:
        if suffix == '-SC1':
          S = StandardScaler()
        elif suffix == '-SC2':
          S = Pipeline( [('standardizer', StandardScaler()), ('scaler', MinMaxScaler())]  )
        sequence = S.fit_transform( sequence )
      else:
        sequence = S.transform(sequence)

    X, y = list(), list()
    for i in range(len(sequence)):
      # find the end of this pattern
      end_ix = i + n_days
      # check if we are beyond the sequence
      if end_ix > len(sequence)-1:
        break
      # gather input and output parts of the pattern
      seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
      X.append(seq_x)
      y.append(seq_y)

    return np.array(X), np.array(y), S


  # split the 1d sequence into forecasting training set
  X,Y={},{}

  print( f'Train using data from first {n_days}; early stop using data from next {n_days}; test on a different sensor')

  trn = pa_df.loc[grps.groups[s1]][key_to_predict][0:365//3].values
  val = pa_df.loc[grps.groups[s1]][key_to_predict][(365//3):(2*365//3)].values

  # test on a different sensor
  tst = pa_df.loc[grps.groups[s2]][key_to_predict].values

  t='trn'; X[t], Y[t], Scaler = split_sequence(trn, n_days)
  t='val'; X[t], Y[t], _ = split_sequence(val, n_days, Scaler)
  t='tst'; X[t], Y[t], _ = split_sequence(tst, n_days, Scaler)

  # no longer true after rescaling...
  # t='trn'; assert trn[:n_days+1][-1] == Y[t][0]   #  trn[:15] is a concatenation of  X[t][0] and Y[t][0]

  model = Sequential()
  if 'bi' in mid:
    model.add(Bidirectional( LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features))) )
    model.add(Bidirectional( LSTM(50, activation='relu', ) ))
  else:
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features)) )
    model.add(LSTM(50, activation='relu'))

  model.add(Dense(1))

  LR=0.0001
  opt = keras.optimizers.Adam(learning_rate=LR )
  model.compile(optimizer=opt, loss=LOSS )

  C = []
  C.append( tf.keras.callbacks.EarlyStopping(monitor="val_loss",
            min_delta=0,
            patience=0,
            verbose=0,
            mode="auto",
            baseline=None,
            restore_best_weights=False,
            start_from_epoch=0,)
  )
  t='trn'
  h = model.fit(X[t], Y[t], validation_data=(X['val'], Y['val']), epochs=5000, verbose=0, callbacks=C)
  hist = h.history

  for kk in hist.keys():
    plt.plot( hist[kk], label=kk )
  plt.title( mid )
  plt.legend()
  return model, X, Y







n_days, n_features = 14, 1 # 2-week period

LOSS='mean_squared_logarithmic_error'
LOSS='mean_absolute_percentage_error'
LOSS='mean_absolute_error'

LOSS='mean_squared_error'

Res_DF=pd.DataFrame( columns=['setting', 'R2', 'RMSE', 'MdAE'] )

for suffix in ['-','-SC1','-SC2']:
  for mid in [f'bilstm-uni', f'lstm-uni']:
    model, X, Y, = train_eval_univariate(s1, s2, mid )
    a,b,c = eval_model(model, X, Y )
    Res_DF.loc[len(Res_DF)] = np.array( [mid+suffix, a,b,c])

Res_DF.head(1000)
# Out:
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=5.397, RMSE=14.187, Spearman=0.378
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=5.361, RMSE=14.584, Spearman=0.315
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.605, RMSE=1.483, Spearman=0.400
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.616, RMSE=1.389, Spearman=0.368
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.147, RMSE=0.293, Spearman=0.431
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.145, RMSE=0.297, Spearman=0.405
# CPU times: user 1min 36s, sys: 1.23 s, total: 1min 37s
# Wall time: 1min 35s
#           setting                   R2                 RMSE  \
# 0     bilstm-uni-   0.3781577205506082    5.397103294372559
# 1       lstm-uni-  0.31512724816095516   5.3608958206176744
# 2  bilstm-uni-SC1  0.39975765889001913   0.6054440778760344
# 3    lstm-uni-SC1   0.3677801763834679   0.6162543946082542
# 4  bilstm-uni-SC2   0.4313793858680509  0.14692423137065191
# 5    lstm-uni-SC2    0.405281443346292  0.14487062043466636
#
#                   MdAE
# 0   14.186850527711723
# 1   14.584389509102115
# 2   1.4825049182647287
# 3    1.389043877310988
# 4  0.29252086795827265
# 5  0.29659110030536867

# %% [markdown]
# # 4b. Develop and evaluate multi-variable forecast models

# %%
Res_DF
# Out:
#           setting                   R2                 RMSE  \
# 0     bilstm-uni-   0.3781577205506082    5.397103294372559
# 1       lstm-uni-  0.31512724816095516   5.3608958206176744
# 2  bilstm-uni-SC1  0.39975765889001913   0.6054440778760344
# 3    lstm-uni-SC1   0.3677801763834679   0.6162543946082542
# 4  bilstm-uni-SC2   0.4313793858680509  0.14692423137065191
# 5    lstm-uni-SC2    0.405281443346292  0.14487062043466636
#
#                   MdAE
# 0   14.186850527711723
# 1   14.584389509102115
# 2   1.4825049182647287
# 3    1.389043877310988
# 4  0.29252086795827265
# 5  0.29659110030536867

# %%
# %%time

from tensorflow.keras.layers import Reshape, Dense, Flatten, Dropout, MaxPooling1D, TimeDistributed, LSTM, BatchNormalization, Input, concatenate, Conv1D

# create multi-variable time-series
def split_df( df, n_days, kk, k, S=None ):
  df = df[ kk ]
  if suffix == '-':
    S=None
    print('dont preprocess')
  else:
    if S is None:
      if suffix =='-SC1':
        S = StandardScaler()
      elif suffix=='-SC2':
        S = Pipeline( [('standardizer', StandardScaler()), ('scaler', MinMaxScaler())] )
      S.fit( df )
    XX = S.fit_transform( df )
    df[ kk ]= XX

  X, y = list(), list()
  n= len(df)

  for i in range(n):
    # find the end of this pattern
    end_ix = i + n_days
    # check if we are beyond the sequence
    if end_ix > len(df)-1:
      break
    # gather input and output parts of the pattern
    seq_x = df.iloc[i:end_ix, : ].values
    seq_y = df.iloc[end_ix, 0 ]
    X.append(seq_x)
    y.append(seq_y)

  return np.array(X), np.array(y), S



def train_eval_multi(s1, s2, L, k = 'pm10.0_atm'):

  n_days, n_features = 14, len(L) # 2-week

  print('window size of', n_days, 'days', n_features , 'features')

  # split the 1d sequence into forecasting training set
  X,Y={},{}

  trn = pa_df.loc[grps.groups[s1]][:365//3]
  val = pa_df.loc[grps.groups[s1]][365//3:(365//3*2)]

  t='trn'; X[t], Y[t], Scaler = split_df(trn, n_days, L, L[0] )
  t='val'; X[t], Y[t], _ = split_df(val, n_days, L, L[0], Scaler )

  # test on a different sensor
  tst = pa_df.loc[grps.groups[s2]]
  t='tst'; X[t], Y[t], _ = split_df( tst, n_days, L, L[0], Scaler )

  #t='trn'; assert Scaler.transform( trn[L] )[n_days, 0 ] == Y[t][0]  #  trn[:15] is a concatenation of  X[t][:14] and Y[t][0]

  # https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

  for t in ['trn','val','tst']:
    n_subsamples = 2
    n_days2 = n_days// n_subsamples
    if 'cnn' in mid:
      nd = n_days*n_features
      X[t] = X[t].reshape( (X[t].shape[0], nd ))

  model2 = Sequential()
  if 'bi' in mid:
    model2.add( Bidirectional(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features))) )
    model2.add( Bidirectional(LSTM(50, activation='relu')) )
  elif 'cnn' in mid:
    model2.add( Reshape((n_days, n_features), input_shape=(nd,)))
    model2.add( Conv1D(14, kernel_size=3, activation='relu'))
    model2.add( Conv1D(14, kernel_size=3, activation='relu'))
    model2.add( BatchNormalization())
    model2.add( MaxPooling1D(pool_size=2) )
    model2.add( Flatten())
  else:
    model2.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features)))
    model2.add(LSTM(50, activation='relu'))
  model2.add(Dense(1))

  LR=0.0001
  opt = keras.optimizers.Adam(learning_rate=LR )
  model2.compile(optimizer=opt, loss=LOSS )

  C = []
  C.append( tf.keras.callbacks.EarlyStopping(monitor="val_loss",
            min_delta=0,
            patience=0,
            verbose=0,
            mode="auto",
            baseline=None,
            restore_best_weights=False,
            start_from_epoch=0,)
  )
  t ='trn'
  h = model2.fit(X[t], Y[t], validation_data=(X['val'], Y['val']), epochs=5000, verbose=0, callbacks=C)
  hist = h.history

  plt.figure()
  for kk in hist.keys():
    plt.plot( hist[kk], label=kk )
  plt.legend()
  plt.title(L)
  print( model2.summary() )
  return eval_model(model2, X, Y )


for suffix in [ '-', '-SC1', '-SC2' ]:
  for arc in ['', 'bi', 'cnn']:

    if 1:
      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', 'prcp', 'srad']
      mid =arc+f'lstm-{len(L)}vars' + suffix
      a,b,c= train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

    if 0:
      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', 'prcp']
      mid = arc+f'lstm-{len(L)}vars'
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', ]
      mid = arc+f'lstm-{len(L)}vars'
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

    if 1:
      L=['pm10.0_atm', 'srad', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'prcp', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'humidity', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

      L=['pm10.0_atm', 'temperature', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'pressure', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])
# Out:
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_255"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_364 (LSTM)             (None, 14, 50)            11400
#
#  lstm_365 (LSTM)             (None, 50)                20200
#
#  dense_255 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=63.000, RMSE=127.836, Spearman=0.134
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_256"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_366 (LSTM)             (None, 14, 50)            10600
#
#  lstm_367 (LSTM)             (None, 50)                20200
#
#  dense_256 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=41.123, RMSE=56.204, Spearman=0.002
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_257"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_368 (LSTM)             (None, 14, 50)            10600
#
#  lstm_369 (LSTM)             (None, 50)                20200
#
#  dense_257 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.485, RMSE=12.210, Spearman=0.318
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_258"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_370 (LSTM)             (None, 14, 50)            10600
#
#  lstm_371 (LSTM)             (None, 50)                20200
#
#  dense_258 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=6.545, RMSE=11.959, Spearman=0.113
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_259"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_372 (LSTM)             (None, 14, 50)            10600
#
#  lstm_373 (LSTM)             (None, 50)                20200
#
#  dense_259 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=7.803, RMSE=13.682, Spearman=-0.116
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_260"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_374 (LSTM)             (None, 14, 50)            10600
#
#  lstm_375 (LSTM)             (None, 50)                20200
#
#  dense_260 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=33.797, RMSE=62.050, Spearman=0.042
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_261"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_182 (Bidirec  (None, 14, 100)           22800
#  tional)
#
#  bidirectional_183 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_261 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=547.440, RMSE=654.187, Spearman=-0.062
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_262"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_184 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_185 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_262 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=77.681, RMSE=115.883, Spearman=-0.042
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_263"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_186 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_187 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_263 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.307, RMSE=10.816, Spearman=0.431
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_264"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_188 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_189 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_264 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=6.827, RMSE=10.607, Spearman=0.152
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_265"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_190 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_191 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_265 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=10.144, RMSE=24.649, Spearman=0.158
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_266"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_192 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_193 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_266 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=24.748, RMSE=51.111, Spearman=-0.322
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_267"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_73 (Reshape)        (None, 14, 6)             0
#
#  conv1d_146 (Conv1D)         (None, 12, 14)            266
#
#  conv1d_147 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_73 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_73 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_73 (Flatten)        (None, 70)                0
#
#  dense_267 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.699, RMSE=14.164, Spearman=-0.059
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_268"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_74 (Reshape)        (None, 14, 2)             0
#
#  conv1d_148 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_149 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_74 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_74 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_74 (Flatten)        (None, 70)                0
#
#  dense_268 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.361, RMSE=13.389, Spearman=-0.172
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_269"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_75 (Reshape)        (None, 14, 2)             0
#
#  conv1d_150 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_151 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_75 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_75 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_75 (Flatten)        (None, 70)                0
#
#  dense_269 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.976, RMSE=13.594, Spearman=0.257
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_270"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_76 (Reshape)        (None, 14, 2)             0
#
#  conv1d_152 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_153 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_76 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_76 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_76 (Flatten)        (None, 70)                0
#
#  dense_270 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=5.967, RMSE=10.769, Spearman=0.270
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_271"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_77 (Reshape)        (None, 14, 2)             0
#
#  conv1d_154 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_155 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_77 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_77 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_77 (Flatten)        (None, 70)                0
#
#  dense_271 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.066, RMSE=12.028, Spearman=0.052
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_272"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_78 (Reshape)        (None, 14, 2)             0
#
#  conv1d_156 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_157 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_78 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_78 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_78 (Flatten)        (None, 70)                0
#
#  dense_272 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=12.715, RMSE=20.768, Spearman=-0.186
# window size of 14 days 6 features
# Model: "sequential_273"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_388 (LSTM)             (None, 14, 50)            11400
#
#  lstm_389 (LSTM)             (None, 50)                20200
#
#  dense_273 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.605, RMSE=0.952, Spearman=0.321
# window size of 14 days 2 features
# Model: "sequential_274"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_390 (LSTM)             (None, 14, 50)            10600
#
#  lstm_391 (LSTM)             (None, 50)                20200
#
#  dense_274 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.606, RMSE=0.950, Spearman=0.376
# window size of 14 days 2 features
# Model: "sequential_275"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_392 (LSTM)             (None, 14, 50)            10600
#
#  lstm_393 (LSTM)             (None, 50)                20200
#
#  dense_275 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# <timed exec>:102: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
# None
# tst, MdAE=0.571, RMSE=0.921, Spearman=0.383
# window size of 14 days 2 features
# Model: "sequential_276"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_394 (LSTM)             (None, 14, 50)            10600
#
#  lstm_395 (LSTM)             (None, 50)                20200
#
#  dense_276 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.468, RMSE=0.868, Spearman=0.442
# window size of 14 days 2 features
# Model: "sequential_277"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_396 (LSTM)             (None, 14, 50)            10600
#
#  lstm_397 (LSTM)             (None, 50)                20200
#
#  dense_277 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.654, RMSE=0.966, Spearman=0.119
# window size of 14 days 2 features
# Model: "sequential_278"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_398 (LSTM)             (None, 14, 50)            10600
#
#  lstm_399 (LSTM)             (None, 50)                20200
#
#  dense_278 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.611, RMSE=0.945, Spearman=0.318
# window size of 14 days 6 features
# Model: "sequential_279"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_194 (Bidirec  (None, 14, 100)           22800
#  tional)
#
#  bidirectional_195 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_279 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.573, RMSE=0.972, Spearman=-0.133
# window size of 14 days 2 features
# Model: "sequential_280"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_196 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_197 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_280 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.581, RMSE=0.961, Spearman=0.193
# window size of 14 days 2 features
# Model: "sequential_281"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_198 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_199 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_281 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.478, RMSE=0.865, Spearman=0.399
# window size of 14 days 2 features
# Model: "sequential_282"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_200 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_201 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_282 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.466, RMSE=0.841, Spearman=0.423
# window size of 14 days 2 features
# Model: "sequential_283"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_202 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_203 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_283 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.484, RMSE=0.905, Spearman=0.304
# window size of 14 days 2 features
# Model: "sequential_284"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_204 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_205 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_284 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.519, RMSE=0.892, Spearman=0.395
# window size of 14 days 6 features
# Model: "sequential_285"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_79 (Reshape)        (None, 14, 6)             0
#
#  conv1d_158 (Conv1D)         (None, 12, 14)            266
#
#  conv1d_159 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_79 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_79 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_79 (Flatten)        (None, 70)                0
#
#  dense_285 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.634, RMSE=0.959, Spearman=0.081
# window size of 14 days 2 features
# Model: "sequential_286"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_80 (Reshape)        (None, 14, 2)             0
#
#  conv1d_160 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_161 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_80 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_80 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_80 (Flatten)        (None, 70)                0
#
#  dense_286 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.711, RMSE=1.015, Spearman=-0.185
# window size of 14 days 2 features
# Model: "sequential_287"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_81 (Reshape)        (None, 14, 2)             0
#
#  conv1d_162 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_163 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_81 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_81 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_81 (Flatten)        (None, 70)                0
#
#  dense_287 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.461, RMSE=0.832, Spearman=0.368
# window size of 14 days 2 features
# Model: "sequential_288"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_82 (Reshape)        (None, 14, 2)             0
#
#  conv1d_164 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_165 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_82 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_82 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_82 (Flatten)        (None, 70)                0
#
#  dense_288 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.685, RMSE=1.038, Spearman=0.192
# window size of 14 days 2 features
# Model: "sequential_289"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_83 (Reshape)        (None, 14, 2)             0
#
#  conv1d_166 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_167 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_83 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_83 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_83 (Flatten)        (None, 70)                0
#
#  dense_289 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.706, RMSE=0.935, Spearman=0.286
# window size of 14 days 2 features
# Model: "sequential_290"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_84 (Reshape)        (None, 14, 2)             0
#
#  conv1d_168 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_169 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_84 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_84 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_84 (Flatten)        (None, 70)                0
#
#  dense_290 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.564, RMSE=0.945, Spearman=0.425
# window size of 14 days 6 features
# Model: "sequential_291"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_412 (LSTM)             (None, 14, 50)            11400
#
#  lstm_413 (LSTM)             (None, 50)                20200
#
#  dense_291 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.146, RMSE=0.191, Spearman=-0.256
# window size of 14 days 2 features
# Model: "sequential_292"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_414 (LSTM)             (None, 14, 50)            10600
#
#  lstm_415 (LSTM)             (None, 50)                20200
#
#  dense_292 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.143, RMSE=0.180, Spearman=-0.083
# window size of 14 days 2 features
# Model: "sequential_293"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_416 (LSTM)             (None, 14, 50)            10600
#
#  lstm_417 (LSTM)             (None, 50)                20200
#
#  dense_293 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.110, RMSE=0.155, Spearman=0.385
# window size of 14 days 2 features
# Model: "sequential_294"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_418 (LSTM)             (None, 14, 50)            10600
#
#  lstm_419 (LSTM)             (None, 50)                20200
#
#  dense_294 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# ...
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_206 (Bidirec  (None, 14, 100)           22800
#  tional)
#
#  bidirectional_207 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_297 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.155, RMSE=0.176, Spearman=0.346
# window size of 14 days 2 features
# Model: "sequential_298"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_208 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_209 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_298 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.136, RMSE=0.178, Spearman=-0.052
# window size of 14 days 2 features
# Model: "sequential_299"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_210 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_211 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_299 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.100, RMSE=0.147, Spearman=0.434
# window size of 14 days 2 features
# Model: "sequential_300"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_212 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_213 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_300 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.137, RMSE=0.171, Spearman=0.220
# window size of 14 days 2 features
# Model: "sequential_301"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_214 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_215 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_301 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.140, RMSE=0.178, Spearman=0.096
# window size of 14 days 2 features
# Model: "sequential_302"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_216 (Bidirec  (None, 14, 100)           21200
#  tional)
#
#  bidirectional_217 (Bidirec  (None, 100)               60400
#  tional)
#
#  dense_302 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.134, RMSE=0.165, Spearman=0.305
# window size of 14 days 6 features
# Model: "sequential_303"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_85 (Reshape)        (None, 14, 6)             0
#
#  conv1d_170 (Conv1D)         (None, 12, 14)            266
#
#  conv1d_171 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_85 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_85 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_85 (Flatten)        (None, 70)                0
#
#  dense_303 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.082, RMSE=0.190, Spearman=-0.003
# window size of 14 days 2 features
# Model: "sequential_304"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_86 (Reshape)        (None, 14, 2)             0
#
#  conv1d_172 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_173 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_86 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_86 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_86 (Flatten)        (None, 70)                0
#
#  dense_304 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.091, RMSE=0.187, Spearman=0.184
# window size of 14 days 2 features
# Model: "sequential_305"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_87 (Reshape)        (None, 14, 2)             0
#
#  conv1d_174 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_175 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_87 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_87 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_87 (Flatten)        (None, 70)                0
#
#  dense_305 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.060, RMSE=0.164, Spearman=0.301
# window size of 14 days 2 features
# Model: "sequential_306"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_88 (Reshape)        (None, 14, 2)             0
#
#  conv1d_176 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_177 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_88 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_88 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_88 (Flatten)        (None, 70)                0
#
#  dense_306 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.064, RMSE=0.177, Spearman=0.102
# window size of 14 days 2 features
# Model: "sequential_307"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_89 (Reshape)        (None, 14, 2)             0
#
#  conv1d_178 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_179 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_89 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_89 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_89 (Flatten)        (None, 70)                0
#
#  dense_307 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.048, RMSE=0.190, Spearman=0.172
# window size of 14 days 2 features
# Model: "sequential_308"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_90 (Reshape)        (None, 14, 2)             0
#
#  conv1d_180 (Conv1D)         (None, 12, 14)            98
#
#  conv1d_181 (Conv1D)         (None, 10, 14)            602
#
#  batch_normalization_90 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_90 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_90 (Flatten)        (None, 70)                0
#
#  dense_308 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.057, RMSE=0.175, Spearman=0.059
# CPU times: user 7min 48s, sys: 5.18 s, total: 7min 53s
# Wall time: 7min 47s

# %%
LOSS
# Out:
# 'mean_squared_error'

# %%
Res_DF.R2=Res_DF.R2.astype(float)
Res_DF.MdAE=Res_DF.MdAE.astype(float)
Res_DF.RMSE=Res_DF.RMSE.astype(float)

# %%
import plotly.express as px
px.bar( Res_DF.iloc[:24,:], y='MdAE', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c60f60c3-6374-4643-8cf6-f2905d518442" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c60f60c3-6374-4643-8cf6-f2905d518442")) {                    Plotly.newPlot(                        "c60f60c3-6374-4643-8cf6-f2905d518442",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eMdAE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bilstm-uni-","lstm-uni-","bilstm-uni-SC1","lstm-uni-SC1","bilstm-uni-SC2","lstm-uni-SC2","lstm-6vars-","lstm-srad-","lstm-prcp-","lstm-humidity-","lstm-temperature-","lstm-pressure-","bilstm-6vars-","bilstm-srad-","bilstm-prcp-","bilstm-humidity-","bilstm-temperature-","bilstm-pressure-","cnnlstm-6vars-","cnnlstm-srad-","cnnlstm-prcp-","cnnlstm-humidity-","cnnlstm-temperature-","cnnlstm-pressure-"],"xaxis":"x","y":[14.186850527711723,14.584389509102115,1.4825049182647287,1.389043877310988,0.29252086795827265,0.29659110030536867,127.83576763677911,56.204485440206675,12.210287908714731,11.959320312055766,13.681566473744923,62.050141781585054,654.1867602774832,115.88266749476594,10.816291944425892,10.606902235854543,24.64861644649658,51.11107164917188,14.163853543684345,13.389148054397932,13.593761607055026,10.768678297878099,12.02811346344944,20.76752155010012],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333 ...

# %%
px.bar( Res_DF.iloc[24:,:], y='MdAE', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="17d2e220-c913-4399-b80e-b1a7ac99ddb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17d2e220-c913-4399-b80e-b1a7ac99ddb4")) {                    Plotly.newPlot(                        "17d2e220-c913-4399-b80e-b1a7ac99ddb4",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eMdAE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["lstm-6vars-SC1","lstm-srad-SC1","lstm-prcp-SC1","lstm-humidity-SC1","lstm-temperature-SC1","lstm-pressure-SC1","bilstm-6vars-SC1","bilstm-srad-SC1","bilstm-prcp-SC1","bilstm-humidity-SC1","bilstm-temperature-SC1","bilstm-pressure-SC1","cnnlstm-6vars-SC1","cnnlstm-srad-SC1","cnnlstm-prcp-SC1","cnnlstm-humidity-SC1","cnnlstm-temperature-SC1","cnnlstm-pressure-SC1","lstm-6vars-SC2","lstm-srad-SC2","lstm-prcp-SC2","lstm-humidity-SC2","lstm-temperature-SC2","lstm-pressure-SC2","bilstm-6vars-SC2","bilstm-srad-SC2","bilstm-prcp-SC2","bilstm-humidity-SC2","bilstm-temperature-SC2","bilstm-pressure-SC2","cnnlstm-6vars-SC2","cnnlstm-srad-SC2","cnnlstm-prcp-SC2","cnnlstm-humidity-SC2","cnnlstm-temperature-SC2","cnnlstm-pressure-SC2"],"xaxis":"x","y":[0.9515840194049737,0.9503280535197864,0.9206073736615404,0.868342746540308,0.9659265528836691,0.9447295843075033,0.9721037903666647,0.9607807213702572,0.8649862603813232,0.8412190130047346,0.905460888157421,0.8915091422499078,0.9588012379314611,1.014846368617461,0.8322915425795314,1.0377468020163143,0.93514332417381,0.9448272089042637,0.19147550924000192,0.1804895995509237,0.15499090521463063,0.17021796349699142,0.17478990629529725,0.16435621398192132,0.17636842241013573,0.1784272548361522,0.14713810260136373,0.1711438421184937,0.1783593970876672,0.16484867032949704,0.18975422836469524,0.18661931454105712,0.16400330963277285,0.17721239604310945,0.18994591540310937,0.17548572980353647],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outline ...

# %%
px.bar( Res_DF, y='R2', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="56af4917-d1ef-4582-b6fd-b4e9cde04a60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56af4917-d1ef-4582-b6fd-b4e9cde04a60")) {                    Plotly.newPlot(                        "56af4917-d1ef-4582-b6fd-b4e9cde04a60",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eR2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bilstm-uni-","lstm-uni-","bilstm-uni-SC1","lstm-uni-SC1","bilstm-uni-SC2","lstm-uni-SC2","lstm-6vars-","lstm-srad-","lstm-prcp-","lstm-humidity-","lstm-temperature-","lstm-pressure-","bilstm-6vars-","bilstm-srad-","bilstm-prcp-","bilstm-humidity-","bilstm-temperature-","bilstm-pressure-","cnnlstm-6vars-","cnnlstm-srad-","cnnlstm-prcp-","cnnlstm-humidity-","cnnlstm-temperature-","cnnlstm-pressure-","lstm-6vars-SC1","lstm-srad-SC1","lstm-prcp-SC1","lstm-humidity-SC1","lstm-temperature-SC1","lstm-pressure-SC1","bilstm-6vars-SC1","bilstm-srad-SC1","bilstm-prcp-SC1","bilstm-humidity-SC1","bilstm-temperature-SC1","bilstm-pressure-SC1","cnnlstm-6vars-SC1","cnnlstm-srad-SC1","cnnlstm-prcp-SC1","cnnlstm-humidity-SC1","cnnlstm-temperature-SC1","cnnlstm-pressure-SC1","lstm-6vars-SC2","lstm-srad-SC2","lstm-prcp-SC2","lstm-humidity-SC2","lstm-temperature-SC2","lstm-pressure-SC2","bilstm-6vars-SC2","bilstm-srad-SC2","bilstm-prcp-SC2","bilstm-humidity-SC2","bilstm-temperature-SC2","bilstm-pressure-SC2","cnnlstm-6vars-SC2","cnnlstm-srad-SC2","cnnlstm-prcp-SC2","cnnlstm-humidity-SC2","cnnlstm-temperature-SC2","cnnlstm-pressure-SC2"],"xaxis":"x","y":[0.3781577205506082,0.31512724816095516,0.39975765889001913,0.3677801763834679,0.4313793858680509,0.405281443346292,0.13425123069700043,0.00191294909192522,0.3181721214344954,0.11323640197684304,-0.11610422998736036,0.04228232156567895,-0.06240346020814792,-0.04225235152115471,0.43089931015483846,0.1522929200001872,0.15801345224875363,-0.3222384960808893,-0.05906859900379435,-0.17169672007696002,0.25706375565037226,0.27002732615937824,0.05201495477472333,-0.18608095394653915,0.32115344711362775,0.37638601916852404,0.38328509566796537,0.4418544714301012,0.1194718362403608,0.31798702865951695,-0.13267780335947726,0.193327460962132,0.3988040287232822,0.42335143769152955,0.3042489544998889,0.39450679608920547,0.08081838756582656,-0.18547225679224336,0.3677101075293719,0.19236925203859273,0.28586788219250614,0.42484189240578646,-0.25599399156110386,-0.08303103710299428,0.3849803456864715,0.2770147865401249,0.14148733144713346,0.3197802363235513,0.34630955323617085,-0.05231687522326393,0.43448808423641133,0.22046297752533697,0.09646150205563037,0.30532274234513507,-0.003147687176283132,0.18389189194441363,0.3009066007844043,0.10172249362149156,0.172469003724284,0.05907387151162733],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %%
px.bar( Res_DF, y='RMSE', x='setting' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dfea2975-7826-4c9e-811a-cbe8758c1a17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfea2975-7826-4c9e-811a-cbe8758c1a17")) {                    Plotly.newPlot(                        "dfea2975-7826-4c9e-811a-cbe8758c1a17",                        [{"alignmentgroup":"True","hovertemplate":"setting=%{x}\u003cbr\u003eRMSE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bilstm-uni-","lstm-uni-","bilstm-uni-SC1","lstm-uni-SC1","bilstm-uni-SC2","lstm-uni-SC2","lstm-6vars-","lstm-srad-","lstm-prcp-","lstm-humidity-","lstm-temperature-","lstm-pressure-","bilstm-6vars-","bilstm-srad-","bilstm-prcp-","bilstm-humidity-","bilstm-temperature-","bilstm-pressure-","cnnlstm-6vars-","cnnlstm-srad-","cnnlstm-prcp-","cnnlstm-humidity-","cnnlstm-temperature-","cnnlstm-pressure-","lstm-6vars-SC1","lstm-srad-SC1","lstm-prcp-SC1","lstm-humidity-SC1","lstm-temperature-SC1","lstm-pressure-SC1","bilstm-6vars-SC1","bilstm-srad-SC1","bilstm-prcp-SC1","bilstm-humidity-SC1","bilstm-temperature-SC1","bilstm-pressure-SC1","cnnlstm-6vars-SC1","cnnlstm-srad-SC1","cnnlstm-prcp-SC1","cnnlstm-humidity-SC1","cnnlstm-temperature-SC1","cnnlstm-pressure-SC1","lstm-6vars-SC2","lstm-srad-SC2","lstm-prcp-SC2","lstm-humidity-SC2","lstm-temperature-SC2","lstm-pressure-SC2","bilstm-6vars-SC2","bilstm-srad-SC2","bilstm-prcp-SC2","bilstm-humidity-SC2","bilstm-temperature-SC2","bilstm-pressure-SC2","cnnlstm-6vars-SC2","cnnlstm-srad-SC2","cnnlstm-prcp-SC2","cnnlstm-humidity-SC2","cnnlstm-temperature-SC2","cnnlstm-pressure-SC2"],"xaxis":"x","y":[5.397103294372559,5.3608958206176744,0.6054440778760344,0.6162543946082542,0.14692423137065191,0.14487062043466636,63.000434967041016,41.12254437255859,3.48504736328125,6.544845565795899,7.80346240234375,33.79679010009765,547.4398154296875,77.68079193115234,3.3073530292510984,6.827168876647949,10.144171501159668,24.747541229248046,3.6993812446594236,4.360636177301407,3.9762267768383026,5.967003860473633,4.065781745910645,12.715128997802735,0.6054691017262732,0.6055387817049703,0.5709701473074708,0.4677983791260887,0.653628052917148,0.6106433509468359,0.5732373779720629,0.5807169581757993,0.47756458527137524,0.46599230543960046,0.48383998419018326,0.5189023689308896,0.6337271210611662,0.7114407300469452,0.46133226650209513,0.6854409045736417,0.7060890435113663,0.5641906711585272,0.14602286685367588,0.14298981638618696,0.11041798233355533,0.13657228194448556,0.13708010915093366,0.1357122927623966,0.15535317041969188,0.13621445228854584,0.10038553655112532,0.13687899254533853,0.1400396142597064,0.13390824413047414,0.08168994284614692,0.09066717430301335,0.060242890901031854,0.0635294425746669,0.047790506300018465,0.05678155725662071],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#f ...

# %%
def compare( met_name='MdAE'  ):
  plt.figure( figsize=(20,3))
  M = Res_DF.shape[0]
  thickness = 4
  for i,r in enumerate( Res_DF.iterrows() ):
    k = r[1]['setting']
    m = r[1][ met_name ]
    n=len(m)
    q=365//3
    a=np.arange( 0, q*n, q )
    plt.bar( a+i*thickness, m, thickness, label = k )
  plt.legend()
  plt.title( f'{met_name} of test set for each method compared' )

#compare()

# %% [markdown]
# ## Performance measures achieved by different model-variable combinations

# %%
Res_DF.head(1000)
# Out:
#                     setting        R2        RMSE        MdAE
# 0               bilstm-uni-  0.378158    5.397103   14.186851
# 1                 lstm-uni-  0.315127    5.360896   14.584390
# 2            bilstm-uni-SC1  0.399758    0.605444    1.482505
# 3              lstm-uni-SC1  0.367780    0.616254    1.389044
# 4            bilstm-uni-SC2  0.431379    0.146924    0.292521
# 5              lstm-uni-SC2  0.405281    0.144871    0.296591
# 6               lstm-6vars-  0.134251   63.000435  127.835768
# 7                lstm-srad-  0.001913   41.122544   56.204485
# 8                lstm-prcp-  0.318172    3.485047   12.210288
# 9            lstm-humidity-  0.113236    6.544846   11.959320
# 10        lstm-temperature- -0.116104    7.803462   13.681566
# 11           lstm-pressure-  0.042282   33.796790   62.050142
# 12            bilstm-6vars- -0.062403  547.439815  654.186760
# 13             bilstm-srad- -0.042252   77.680792  115.882667
# 14             bilstm-prcp-  0.430899    3.307353   10.816292
# 15         bilstm-humidity-  0.152293    6.827169   10.606902
# 16      bilstm-temperature-  0.158013   10.144172   24.648616
# 17         bilstm-pressure- -0.322238   24.747541   51.111072
# 18           cnnlstm-6vars- -0.059069    3.699381   14.163854
# 19            cnnlstm-srad- -0.171697    4.360636   13.389148
# 20            cnnlstm-prcp-  0.257064    3.976227   13.593762
# 21        cnnlstm-humidity-  0.270027    5.967004   10.768678
# 22     cnnlstm-temperature-  0.052015    4.065782   12.028113
# 23        cnnlstm-pressure- -0.186081   12.715129   20.767522
# 24           lstm-6vars-SC1  0.321153    0.605469    0.951584
# 25            lstm-srad-SC1  0.376386    0.605539    0.950328
# 26            lstm-prcp-SC1  0.383285    0.570970    0.920607
# 27        lstm-humidity-SC1  0.441854    0.467798    0.868343
# 28     lstm-temperature-SC1  0.119472    0.653628    0.965927
# 29        lstm-pressure-SC1  0.317987    0.610643    0.944730
# 30         bilstm-6vars-SC1 -0.132678    0.573237    0.972104
# 31          bilstm-srad-SC1  0.193327    0.580717    0.960781
# 32          bilstm-prcp-SC1  0.398804    0.477565    0.864986
# 33      bilstm-humidity-SC1  0.423351    0.465992    0.841219
# 34   bilstm-temperature-SC1  0.304249    0.483840    0.905461
# 35      bilstm-pressure-SC1  0.394507    0.518902    0.891509
# 36        cnnlstm-6vars-SC1  0.080818    0.633727    0.958801
# 37         cnnlstm-srad-SC1 -0.185472    0.711441    1.014846
# 38         cnnlstm-prcp-SC1  0.367710    0.461332    0.832292
# 39     cnnlstm-humidity-SC1  0.192369    0.685441    1.037747
# 40  cnnlstm-temperature-SC1  0.285868    0.706089    0.935143
# 41     cnnlstm-pressure-SC1  0.424842    0.564191    0.944827
# 42           lstm-6vars-SC2 -0.255994    0.146023    0.191476
# 43            lstm-srad-SC2 -0.083031    0.142990    0.180490
# 44            lstm-prcp-SC2  0.384980    0.110418    0.154991
# 45        lstm-humidity-SC2  0.277015    0.136572    0.170218
# 46     lstm-temperature-SC2  0.141487    0.137080    0.174790
# 47        lstm-pressure-SC2  0.319780    0.135712    0.164356
# 48         bilstm-6vars-SC2  0.346310    0.155353    0.176368
# 49          bilstm-srad-SC2 -0.052317    0.136214    0.178427
# 50          bilstm-prcp-SC2  0.434488    0.100386    0.147138
# 51      bilstm-humidity-SC2  0.220463    0.136879    0.171144
# 52   bilstm-temperature-SC2  0.096462    0.140040    0.178359
# 53      bilstm-pressure-SC2  0.305323    0.133908    0.164849
# 54        cnnlstm-6vars-SC2 -0.003148    0.081690    0.189754
# 55         cnnlstm-srad-SC2  0.183892    0.090667    0.186619
# 56         cnnlstm-prcp-SC2  0.300907    0.060243    0.164003
# 57     cnnlstm-humidity-SC2  0.101722    0.063529    0.177212
# 58  cnnlstm-temperature-SC2  0.172469    0.047791    0.189946
# 59     cnnlstm-pressure-SC2  0.059074    0.056782    0.175486
