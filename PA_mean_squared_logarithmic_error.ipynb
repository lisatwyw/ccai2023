# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/ccai2023/blob/main/PA_mean_squared_logarithmic_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Administrative setup
#
# - Execute code below to mount drive, install packages, and download resources.
#
# - Click on these buttons when the 2 pop-up windows show up:
#
# <img src="https://raw.githubusercontent.com/lisatwyw/CS4SocialGood/main/ccai/Mount.png" width="500"/>

# %%
# mount drive for permanent storage

import os, sys
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

try:
  # !mkdir /content/drive/MyDrive/purple_air
  # !mkdir /content/drive/MyDrive/purple_air/packages
except:
  pass

os.chdir('/content/drive/MyDrive/purple_air/')
nb_path = 'mypackages'

try:
  # create symbolic path
  os.symlink('/content/drive/MyDrive/purple_air/packages', nb_path)

  # install once to symbolic path
  # !pip install --target=$nb_path lale
  # !pip install --target=$nb_path daymetpy
  # !pip install --target=$nb_path geomdl
  #!pip install --target=$nb_path -U fastapi python-multipart uvicorn kaleido
  # !pip install --target=$nb_path -U plotly
except:
  pass

sys.path.insert(0, '/content/drive/MyDrive/purple_air/')

# !ls /content/drive/MyDrive/purple_air/
# Out:
# Mounted at /content/drive
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# mkdir: cannot create directory ‘/content/drive/MyDrive/purple_air’: File exists
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# mkdir: cannot create directory ‘/content/drive/MyDrive/purple_air/packages’: File exists
# 'Copy of PA_Oakland_2012_daily.csv'   PA_data_for_modeling_2017.csv
# 'Copy of PA_Oakland_2013_daily.csv'   PA_data_for_modeling_2018.csv
# 'Copy of PA_Oakland_2014_daily.csv'   PA_data_for_modeling_2019.csv
# 'Copy of PA_Oakland_2015_daily.csv'   PA_data_for_modeling_2020.csv
# 'Copy of PA_Oakland_2016_daily.csv'   PA_data_for_modeling_2021.csv
# 'Copy of PA_Oakland_2017_daily.csv'   PA_data_for_modeling_2022.csv
# 'Copy of PA_Oakland_2018_daily.csv'   PA_Oakland_2012_daily.csv
# 'Copy of PA_Oakland_2019_daily.csv'   PA_Oakland_2013_daily.csv
# 'Copy of PA_Oakland_2020_daily.csv'   PA_Oakland_2014_daily.csv
# 'Copy of PA_Oakland_2021_daily.csv'   PA_Oakland_2015_daily.csv
#  Lat_long_PA_sensors_full.csv	      PA_Oakland_2016_daily.csv
#  model.py			      PA_Oakland_2017_daily.csv
#  mypackages			      PA_Oakland_2018_daily.csv
#  Oakland_daily_daymet_data_2017.csv   PA_Oakland_2019_daily.csv
#  Oakland_daily_daymet_data_2018.csv   PA_Oakland_2020_daily.csv
#  Oakland_daily_daymet_data_2019.csv   PA_Oakland_2021_daily.csv
#  Oakland_daily_daymet_data_2020.csv   __pycache__
#  Oakland_daily_daymet_data_2021.csv   visualization-3.py
#  packages

# %% [markdown]
# ## Check for the precomputed files...

# %% [markdown]
# ```
# Collecting daymetpy
#   Downloading daymetpy-1.0.0.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: daymetpy
#   Building wheel for daymetpy (setup.py) ... done
#   Created wheel for daymetpy: filename=daymetpy-1.0.0-py3-none-any.whl size=4094 sha256=02cba4ef9e6a078a65eae7b80e803da850cb9a51ee06f8d896a974e9ad6c5fca
#   Stored in directory: /root/.cache/pip/wheels/56/d2/10/a37e259b28ccac8537185688acfb45913df0b826d5ad3962d7
# Successfully built daymetpy
# Installing collected packages: daymetpy
# Successfully installed daymetpy-1.0.0
#
#
# Collecting geomdl
#   Downloading geomdl-5.3.1-py2.py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: geomdl
# Successfully installed geomdl-5.3.1
#
#
#
# Collecting fastapi
#   Using cached fastapi-0.104.0-py3-none-any.whl (92 kB)
# Collecting python-multipart
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# Collecting uvicorn
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting kaleido
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Collecting anyio<4.0.0,>=3.7.1 (from fastapi)
#   Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi)
#   Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi)
#   Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting click>=7.0 (from uvicorn)
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting h11>=0.8 (from uvicorn)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting idna>=2.8 (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio>=1.1 (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup (from anyio<4.0.0,>=3.7.1->fastapi)
#   Using cached exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached pydantic_core-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Installing collected packages: kaleido, typing-extensions, sniffio, python-multipart, idna, h11, exceptiongroup, click, annotated-types, uvicorn, pydantic-core, anyio, starlette, pydantic, fastapi
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed annotated-types-0.6.0 anyio-3.7.1 click-8.1.7 exceptiongroup-1.1.3 fastapi-0.104.0 h11-0.14.0 idna-3.4 kaleido-0.2.1 pydantic-2.4.2 pydantic-core-2.10.1 python-multipart-0.0.6 sniffio-1.3.0 starlette-0.27.0 typing-extensions-4.8.0 uvicorn-0.23.2
#
# ```

# %%
import requests
import pandas as pd # circular imports?

from datetime import datetime
import time
import json
import io
from io import StringIO
import geopandas
import matplotlib.pyplot as plt
from matplotlib import cm

import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import MarkerCluster, BeautifyIcon
import branca

# Import the daymetpy package
# import daymetpy

# Import packages for multiprocessing
import itertools
import multiprocessing as mp
from multiprocessing.pool import ThreadPool

from shapely.geometry import Point, Polygon

import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn' # You can turn off these warnings if you know what you are doing by using
import polars as pol

import math
import numpy as np

# %% [markdown]
# ## 2a. Steps to download PurpleAir
#
# 1. Visit [this page](https://develop.purpleair.com/keys)
# 2. Click "Add" button (top left)
# 3. Click "Add" button (bottom right)
#
# ![image](https://global.discourse-cdn.com/business7/uploads/purpleair/optimized/2X/d/d47145bfc7631a5b48b6aa006c320562a04358ac_2_690x318.png)

# %%
# !curl -X GET "https://api.purpleair.com/v1/keys" -H "X-API-Key: xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxx"
# Out:
# {
#   "api_version" : "V1.0.11-0.0.49",
#   "time_stamp" : 1697772876,
#   "error" : "ApiKeyInvalidError",
#   "description" : "The provided api_key was not valid."
# }

# %%
# !curl -X GET "https://api.purpleair.com/v1/keys"
# Out:
# {
#   "api_version" : "V1.0.11-0.0.49",
#   "time_stamp" : 1697772876,
#   "error" : "ApiKeyMissingError",
#   "description" : "No API key was found in the request."
# }

# %% [markdown]
# # 2b. Read in the pre-downloaded and merged dataframe

# %%
YEAR = 2022

pa_df = pd.read_csv(f'PA_data_for_modeling_{YEAR}.csv')
sensor_list1 = pa_df.drop_duplicates(subset=['latitude', 'longitude'], keep='last') # latest snapshot
sensor_list = pa_df.drop_duplicates(subset=['latitude', 'longitude'], keep='first') # earliest snapshot

key_to_predict ='pm10.0_atm'
max_value = pa_df[key_to_predict ].max()
min_value = pa_df[key_to_predict ].min()
print( min_value, max_value )
nlevels = 5 # color levels
# define colours for each level
ss_colors=['#ff00ff', '#ff40bf', '#ff807f', '#ffc03f', '#ffff00']

mx, mn = np.int64(max_value) -1,  np.int64(min_value)
sensor_list.head()
# Out:
# 0.0 3356.8825
#       Unnamed: 0  sensor                      name   latitude  longitude  \
# 0              0   13997                   Hilltop  37.834310 -122.22653
# 365          365   15645  Redwood Heights, Oakland  37.801030 -122.18855
# 730          730   17927              West Oakland  37.817640 -122.27246
# 1095        1095   18997         Head-Royce School  37.808174 -122.20474
# 1460        1460   19273                Sims Drive  37.821156 -122.20937
#
#        Datestamp   humidity  temperature     pressure  pm10.0_atm  \
# 0     2022-01-01  45.919000    52.233000   996.909000      3.8495
# 365   2022-01-01  43.398000    55.553000  1003.290000      3.7900
# 730   2022-01-01  63.971281    64.467907   998.648163      8.9030
# 1095  2022-01-01  48.510000    52.771000  1005.613000      4.1550
# 1460  2022-01-01  48.233000    51.056000   997.452000      2.5380
#
#       pm10.0_cf_1  prcp    srad
# 0          3.9565   0.0  219.00
# 365        3.7900   0.0  227.48
# 730        8.9205   0.0  216.46
# 1095       4.1550   0.0  224.64
# 1460       2.5385   0.0  220.62

# %%
from folium.features import DivIcon

def draw( sensor_list, ss_filtered_legend_index, annotate=True, description='first' ):
  # create nao
  map = folium.Map(location=[sensor_list['latitude'].mean(), sensor_list['longitude'].mean()], zoom_start=13, control_scale=True)

  # add annotations on the map

  # - for each sensor location, add diamond whose size represents measured value
  for index, row in sensor_list.iterrows():
      local_deformation = math.cos(row['latitude'] * math.pi / 180)
      size = row[ key_to_predict ]*60/max_value * local_deformation

      folium.features.RegularPolygonMarker(
                  location =[row['latitude'], row['longitude']],
                  radius   = size,
                  fill_color=ss_colors[row['color_labels']],
                  color = ss_colors[row['color_labels']],
      ).add_to(map)

      if annotate:
        folium.map.Marker( [row['latitude'], row['longitude']],
                  icon=DivIcon(
                  icon_size=(250,36),
                  icon_anchor=(0,0),
                  html='<div style="font-size: 4pt">%s</div>'% row['sensor'] )
        ).add_to(map)

  sw = sensor_list[['latitude', 'longitude']].min().values.tolist()
  ne = sensor_list[['latitude', 'longitude']].max().values.tolist()

  # # Get maximum quantity of emissions from stationary source
  colormap = branca.colormap.LinearColormap(ss_colors,
                                            index=ss_filtered_legend_index[1:],
                                            vmin=0, vmax=max_value,
                                            caption= f'{key_to_predict} measured on {description} day' )
  colormap.add_to(map)
  if 1:
    svg_style = '<style>svg#legend {font-size: 14px; background-color: white;}</style>'
    map.get_root().header.add_child(folium.Element(svg_style))

  bw = 0.005 # width of bounding box
  map.fit_bounds([ [sw[0]-bw,sw[1]-bw], [ne[0]+bw, ne[1]+bw] ] )
  return map


sensor_list['color_labels'] = pd.cut(sensor_list[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[0]
ss_filtered_legend_index = pd.cut(sensor_list[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[1]
map0 = draw( sensor_list, ss_filtered_legend_index )


sensor_list1['color_labels'] = pd.cut(sensor_list1[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[0]
ss_filtered_legend_index1 = pd.cut(sensor_list1[ key_to_predict ], 5, labels=[0,1,2,3,4], retbins=True)[1]
map1 = draw( sensor_list1, ss_filtered_legend_index1, True, 'last' )

from IPython.core.display import display, HTML
#from IPython.display import IFrame

htmlmap = HTML('<iframe srcdoc="{}" style="float:left; width: {}px; height: {}px; display:inline-block; width: 50%; margin: 0 auto; border: 0px solid black"></iframe>'
           '<iframe srcdoc="{}" style="float:right; width: {}px; height: {}px; display:inline-block; width: 50%; margin: 0 auto; border: 0px solid black"></iframe>'
           .format(map0.get_root().render().replace('"', '&quot;'),100, 300,
                   map1.get_root().render().replace('"', '&quot;'),100, 300))
display(htmlmap)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe srcdoc="<!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#     <style>svg#legend {font-size: 14px; background-color: white;}</style>
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_5440bfc3d48ea4dbadd8409a1f9f06af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;></script>
# </head>
# <body>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_5440bfc3d48ea4dbadd8409a1f9f06af&quot; ></div>
#
# </body>
# <script>
#
#
#             var map_5440bfc3d48ea4dbadd8409a1f9f06af = L.map(
#                 &quot;map_5440bfc3d48ea4dbadd8409a1f9f06af&quot;,
#                 {
#                     center: [37.79476809189189, -122.21982534054055],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#
#
#
#             var tile_layer_e4872a62f9d14a41f97ceeb67a5981d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var regular_polygon_marker_de2efff1d87fa2d846aec364e4089246 = new L.RegularPolygonMarker(
#                 [37.83431, -122.22653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.05434128221704802, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var marker_9d238eb21647cbcf44f41909589f3972 = L.marker(
#                 [37.83431, -122.22653],
#                 {}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var div_icon_6983e338248a4a85426563d7a8adcc0b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e13997\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_9d238eb21647cbcf44f41909589f3972.setIcon(div_icon_6983e338248a4a85426563d7a8adcc0b);
#
#
#             var regular_polygon_marker_e99de17b9775b0b5d77ff049bdd79bf4 = new L.RegularPolygonMarker(
#                 [37.80103, -122.18855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0535254791476388, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var marker_90084a9d7e09e72496aab764ee5a7b56 = L.marker(
#                 [37.80103, -122.18855],
#                 {}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var div_icon_63dd1310482f39eb02b00f486f45cd9d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e15645\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_90084a9d7e09e72496aab764ee5a7b56.setIcon(div_icon_63dd1310482f39eb02b00f486f45cd9d);
#
#
#             var regular_polygon_marker_2f5eae6778335e844b4a9b107afef377 = new L.RegularPolygonMarker(
#                 [37.81764, -122.27246],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12570716581573485, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var marker_f5636e5aae289fe01304ccfdb644f197 = L.marker(
#                 [37.81764, -122.27246],
#                 {}
#             ).addTo(map_5440bfc3d48ea4dbadd8409a1f9f06af);
#
#
#             var div_icon_bc3419637298c64b740796969d519f35 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 4pt\&quot;\u003e17927\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [250, 36]});
#             marker_f5636e5aae289fe01304ccfdb644f197.setIcon(div_icon_bc3419637298c64b740796969d519f35);

# %% [markdown]
# # Naive surface-fitting

# %%
# %matplotlib inline

MAP_WIDTH, MAP_HEIGHT = 300, 100
x = ((MAP_WIDTH/360.0) * (180 + sensor_list.latitude.values ));   # translate x and rescaled
y = ((MAP_HEIGHT/180.0) * (90 - sensor_list.longitude.values ));  # reflect y and rescaled

plt.scatter( x, y, color='red' )
plt.figure()
plt.scatter( sensor_list.latitude.values, sensor_list.longitude.values )

# %%
# %matplotlib inline

import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# test function
def function(data, p00, p10, p01, p20, p11, p02, p21, p12, p03 ):
    x = data[0]
    y = data[1]
    d = p00 + p10*x + p01*y + p20*(x**2) + p11*x*y + p02*(y**2) + p21*(x**2)*y + p12*x*(y**2) + p03*(y**3)
    return d

#x_data = sensor_list.latitude
#y_data = sensor_list.longitude
x_data = ((MAP_WIDTH/360.0) * (180 + sensor_list.latitude));
y_data = ((MAP_HEIGHT/180.0) * (90 - sensor_list.longitude));
z_data = sensor_list[ key_to_predict ]

# get fit parameters from scipy curve fit
parameters, covariance = curve_fit(function, [x_data, y_data], z_data)

# create surface function model
# setup data points for calculating surface model
model_x_data = np.linspace(min(x_data), max(x_data), 30)
model_y_data = np.linspace(min(y_data), max(y_data), 30)

# create coordinate arrays for vectorized evaluations
X, Y = np.meshgrid(model_x_data, model_y_data)

# calculate Z coordinate array
Z = function(np.array([X, Y]), *parameters)

# setup figure object
fig = plt.figure()
ax = plt.axes(projection ="3d")
ax.scatter3D(x_data, y_data, z_data, color = "blue")
ax.scatter3D(X, Y, Z, color = "red")

# %%
parameters
# Out:
# array([-2.39207223e+06, -4.15825446e+02,  1.26940571e+04,  2.11093395e+02,
#        -3.45833002e+02,  3.31416195e+02, -5.22962143e+01,  1.58527078e+02,
#        -1.22053456e+02])

# %%
Z_est = function(np.array([x_data, y_data]), *parameters)
rmse = np.sqrt( np.mean( (Z_est - z_data)**2 ))
rmse
# Out:
# 267.7010773028493

# %% [markdown]
# ## Distances between pairs of sensors

# %%
from sklearn.metrics.pairwise import euclidean_distances
import seaborn as sns

n=sensor_list.shape[0]
dist = np.zeros( (n,n) )
for a,(lat1,long1) in enumerate( zip( list(sensor_list.latitude.values), list(sensor_list.longitude.values) ) ):
    for b,(lat2,long2) in enumerate( zip( list(sensor_list.latitude.values), list(sensor_list.longitude.values) ) ):
      if (a != b):
        # ACOS( SIN(lat1)*SIN(lat2) + COS(lat1)*COS(lat2)*COS(lon2-lon1) ) * 6371000
        d=np.arccos( np.sin(lat1)*np.sin(lat2) + np.cos( lat1)*np.cos(lat2) *np.cos(long1-long2) ) * 6371000
        dist[a,b]= dist[b,a] = d

sns.heatmap( dist )
#plt.imshow(dist)
# Out:
# <Axes: >

# %%
j=1

s1=sensor_list['sensor'].values[j]
q = np.argmax( dist[:, j ] )
s2=sensor_list['sensor'].values[q]

# %% [markdown]
# # Starter's benchmark
#
#
# Goal of this section is to setup a forecast formulation:
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i )$
#
# where $y_i^{t+1}$ is the measured PM10 for sensor $i$ at time $t$+1 given measurements made from timepoints 1 to $t$
#
#
# At the end of this section, we compare performances of different RNN architectures and examine the effects of inclusions of other time-series, e.g.
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i , \text{radiation}_i^{1:t} )$
#
# ...
#
# $\hat{y}_i^{t+1} = f( y^{1:t}_i , \text{radiation}_i^{1:t}, \text{temperature}_i^{1:t}, \text{pressure}_i^{1:t} )$

# %%
grps=pa_df.groupby( by='sensor')
grps.groups.keys()
# Out:
# dict_keys([13997, 15645, 17927, 18997, 19273, 19275, 19299, 19471, 19509, 19664, 20747, 20951, 21285, 22067, 22423, 27135, 34923, 36111, 36153, 37149, 37311, 37491, 37693, 38193, 38613, 38683, 38849, 40059, 41503, 46127, 46331, 50377, 52995, 53219, 53917, 55183, 55811, 55817, 55915, 55961, 55991, 56071, 56281, 59649, 59737, 59921, 60025, 60167, 60333, 60653, 60711, 61359, 61423, 61621, 62303, 62363, 63257, 63509, 63553, 63605, 63849, 63981, 64063, 64429, 64953, 65225, 65251, 65375, 65787, 65849, 65867, 66155, 67261, 67265, 67325, 67359, 67787, 67801, 67943, 67951, 68657, 68711, 68943, 69121, 69131, 69235, 69323, 69587, 69851, 69919, 70015, 70109, 70117, 70663, 70669, 71453, 71461, 71797, 72609, 73149, 73231, 73565, 74161, 74481, 75223, 76071, 76125, 77149, 77397, 77703, 77887, 78475, 80799, 80833, 81017, 81245, 82055, 82105, 83191, 83449, 83737, 84197, 84395, 84721, 84923, 85165, 85357, 85571, 85591, 85835, 87307, 92097, 93855, 95573, 96173, 96309, 97215, 98099, 101515, 103290, 103850, 103852, 105206, 106120, 107652, 108628, 109324, 110306, 110480, 110985, 111530, 111686, 112008, 112308, 112478, 112488, 113222, 113346, 113414, 113608, 114189, 115633, 116023, 116097, 116153, 116229, 116431, 117015, 117935, 117971, 118973, 118977, 119005, 119485, 119607, 119647, 120669, 121107, 121427, 122013, 122061, 126137, 126591, 131817, 137014])

# %%
# sensor lists are identical during this year if the intersection is empty
np.setdiff1d( sensor_list.sensor, sensor_list1.sensor )
# Out:
# array([], dtype=int64)

# %%
if 0:
  s1,s2=13997, 15645 # neighbouring sensors
  s1,s2=87307, 82105 # neighbouring sensors
  s1,s2=87307, 17927 # distant neighbours
  s1,s2=87307, 17927 # distant neighbours

# %%
key_to_predict = 'pm10.0_atm'

print( pa_df.loc[ grps.groups[s1] ][ ['latitude','longitude'] ].head(1) )
print( pa_df.loc[ grps.groups[s2] ][ ['latitude','longitude'] ].head(1) )

xx = np.arange(365)

plt.plot( xx, pa_df.loc[grps.groups[s1]][ key_to_predict ], color='blue')
plt.plot( xx, pa_df.loc[grps.groups[s2]][ key_to_predict ], color='cyan')
# Out:
#      latitude  longitude
# 365  37.80103 -122.18855
#         latitude  longitude
# 60590  37.787052 -122.30934

# %% [markdown]
# # 4a. Develop and evaluate univariate forecast models

# %% [markdown]
# ## Example experimenal setup
#
# | | | |
# | :-- | :-- | :-- |
# | Sensor 1 | TRN | VAL |
# | Sensor 2 | TST  |

# %%
trn = pa_df.loc[grps.groups[s1]].iloc[0:365//3,:]
val = pa_df.loc[grps.groups[s1]].iloc[(365//3):(2*365//3),: ]

trn.head(2)
# Out:
#      Unnamed: 0  sensor                      name  latitude  longitude  \
# 365         365   15645  Redwood Heights, Oakland  37.80103 -122.18855
# 366         366   15645  Redwood Heights, Oakland  37.80103 -122.18855
#
#       Datestamp  humidity  temperature  pressure  pm10.0_atm  pm10.0_cf_1  \
# 365  2022-01-01    43.398       55.553  1003.290       3.790        3.790
# 366  2022-01-02    40.700       55.214  1008.911       6.218        6.218
#
#      prcp    srad
# 365   0.0  227.48
# 366   0.0  259.95

# %%
trn.tail(2)
# Out:
#      Unnamed: 0  sensor                      name  latitude  longitude  \
# 484         484   15645  Redwood Heights, Oakland  37.80103 -122.18855
# 485         485   15645  Redwood Heights, Oakland  37.80103 -122.18855
#
#       Datestamp  humidity  temperature  pressure  pm10.0_atm  pm10.0_cf_1  \
# 484  2022-04-30    42.798       69.854  1001.959       4.762        4.762
# 485  2022-05-01    45.395       66.350   998.348       5.561        5.561
#
#      prcp    srad
# 484   0.0  441.63
# 485   0.0  511.58

# %%
# %%time

# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

import tensorflow as tf

from numpy import array
import keras
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, GRU
from keras.layers import Dense

from keras.layers import Bidirectional
import scipy
from sklearn.preprocessing import StandardScaler

def eval_model(model, X, Y ):
  m1,m2,m3=[],[],[]
  t='tst'
  yhat = model.predict(X[t], verbose=0)
  spearman_stats=scipy.stats.spearmanr( Y[t], yhat.squeeze(), )
  delta = np.abs(Y[t]- yhat.squeeze() )
  MdAE = np.median( delta )
  RMSE = np.sqrt( np.mean( delta**2 ))
  print( f'{t}, MdAE={MdAE:.3f}, RMSE={RMSE:.3f}, Spearman={spearman_stats[0]:.3f}' )
  if len(m1)==0:
    return spearman_stats[0], MdAE, RMSE
  else:
    m1.append( spearman_stats[0] )
    m2.append( MdAE )
    m3.append( RMSE )
    return np.array(m1), np.array(m2), np.array(m3)

def train_eval_univariate(s1, s2, mid = 'lstm-uni', k = 'pm10.0_atm' ):

  # split a univariate sequence into samples
  def split_sequence(sequence, n_days, S=None):

    sequence=sequence.reshape(-1,1) # for rescaling 1D

    if suffix == '-':
      S = None
    else:
      if S is None:
        if suffix == '-SC1':
          S = StandardScaler()
        elif suffix == '-SC2':
          S = Pipeline( [('standardizer', StandardScaler()), ('scaler', MinMaxScaler())]  )
        sequence = S.fit_transform( sequence )
      else:
        sequence = S.transform(sequence)

    X, y = list(), list()
    for i in range(len(sequence)):
      # find the end of this pattern
      end_ix = i + n_days
      # check if we are beyond the sequence
      if end_ix > len(sequence)-1:
        break
      # gather input and output parts of the pattern
      seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
      X.append(seq_x)
      y.append(seq_y)

    return np.array(X), np.array(y), S


  # split the 1d sequence into forecasting training set
  X,Y={},{}

  print( f'Train using data from first {n_days}; early stop using data from next {n_days}; test on a different sensor')

  trn = pa_df.loc[grps.groups[s1]][key_to_predict][0:365//3].values
  val = pa_df.loc[grps.groups[s1]][key_to_predict][(365//3):(2*365//3)].values

  # test on a different sensor
  tst = pa_df.loc[grps.groups[s2]][key_to_predict].values

  t='trn'; X[t], Y[t], Scaler = split_sequence(trn, n_days)
  t='val'; X[t], Y[t], _ = split_sequence(val, n_days, Scaler)
  t='tst'; X[t], Y[t], _ = split_sequence(tst, n_days, Scaler)


  t='trn'
  # no longer true after rescaling... assert trn[:n_days+1][-1] == Y[t][0]   #  trn[:15] is a concatenation of  X[t][0] and Y[t][0]

  model = Sequential()
  if 'bi' in mid:
    model.add(Bidirectional( LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features))) )
    model.add(Bidirectional( LSTM(50, activation='relu', ) ))
  else:
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features)) )
    model.add(LSTM(50, activation='relu'))

  model.add(Dense(1))

  LR=0.0001
  opt = keras.optimizers.Adam(learning_rate=LR )
  model.compile(optimizer=opt, loss=LOSS )

  C = []
  C.append( tf.keras.callbacks.EarlyStopping(monitor="val_loss",
            min_delta=0,
            patience=0,
            verbose=0,
            mode="auto",
            baseline=None,
            restore_best_weights=False,
            start_from_epoch=0,)
  )
  t='trn'
  h = model.fit(X[t], Y[t], validation_data=(X['val'], Y['val']), epochs=5000, verbose=0, callbacks=C)
  hist = h.history

  for kk in hist.keys():
    plt.plot( hist[kk], label=kk )
  plt.title( mid )
  plt.legend()
  return model, X, Y







n_days, n_features = 14, 1 # 2-week period

LOSS='mean_squared_logarithmic_error'
if ( 'Res_DF' in globals())==False:
  Res_DF=pd.DataFrame( columns=['setting', 'R2', 'RMSE', 'MdAE'] )

for suffix in ['-','-SC1','-SC2']:
  for mid in [f'bilstm-uni', f'lstm-uni']:
    model, X, Y, = train_eval_univariate(s1, s2, mid )
    a,b,c = eval_model(model, X, Y )
    Res_DF.loc[len(Res_DF)] = np.array( [mid+suffix, a,b,c])

Res_DF.head(1000)
# Out:
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=4.711, RMSE=14.515, Spearman=0.413
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# <timed exec>:237: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# tst, MdAE=4.299, RMSE=13.279, Spearman=0.419
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# tst, MdAE=0.831, RMSE=1.254, Spearman=-0.320
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# <timed exec>:237: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# tst, MdAE=0.986, RMSE=1.708, Spearman=0.438
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# <timed exec>:237: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# tst, MdAE=0.112, RMSE=0.359, Spearman=-0.459
# Train using data from first 14; early stop using data from next 14; test on a different sensor
# <timed exec>:237: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# tst, MdAE=0.103, RMSE=0.353, Spearman=-0.364
# CPU times: user 1min 16s, sys: 920 ms, total: 1min 17s
# Wall time: 1min 9s
# <timed exec>:237: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#           setting                      R2                   RMSE  \
# 0     bilstm-uni-   [0.41297666852851184]    [4.710880271911621]
# 1       lstm-uni-    [0.4194955694631549]    [4.298763835906982]
# 2  bilstm-uni-SC1  [-0.32017872691555893]   [0.8308834228842736]
# 3    lstm-uni-SC1    [0.4379750156666843]   [0.9857533421792586]
# 4  bilstm-uni-SC2   [-0.4589748593645795]   [0.1115927691292386]
# 5    lstm-uni-SC2   [-0.3643289037561706]  [0.10307162678246712]
#
#                     MdAE
# 0   [14.514670186674422]
# 1   [13.278993236515147]
# 2   [1.2542947815018444]
# 3   [1.7077350524289092]
# 4  [0.35864455846391263]
# 5   [0.3527681033791574]

# %% [markdown]
# # 4b. Develop and evaluate multi-variable forecast models

# %%
Res_DF
# Out:
#           setting                      R2                   RMSE  \
# 0     bilstm-uni-   [0.41297666852851184]    [4.710880271911621]
# 1       lstm-uni-    [0.4194955694631549]    [4.298763835906982]
# 2  bilstm-uni-SC1  [-0.32017872691555893]   [0.8308834228842736]
# 3    lstm-uni-SC1    [0.4379750156666843]   [0.9857533421792586]
# 4  bilstm-uni-SC2   [-0.4589748593645795]   [0.1115927691292386]
# 5    lstm-uni-SC2   [-0.3643289037561706]  [0.10307162678246712]
#
#                     MdAE
# 0   [14.514670186674422]
# 1   [13.278993236515147]
# 2   [1.2542947815018444]
# 3   [1.7077350524289092]
# 4  [0.35864455846391263]
# 5   [0.3527681033791574]

# %%
# %%time

from tensorflow.keras.layers import Reshape, Dense, Flatten, Dropout, MaxPooling1D, TimeDistributed, LSTM, BatchNormalization, Input, concatenate, Conv1D

# create multi-variable time-series
def split_df( df, n_days, kk, k, S=None ):
  df = df[ kk ]
  if suffix == '-':
    S=None
    print('dont preprocess')
  else:
    if S is None:
      if suffix =='-SC1':
        S = StandardScaler()
      elif suffix=='-SC2':
        S = Pipeline( [('standardizer', StandardScaler()), ('scaler', MinMaxScaler())] )
      S.fit( df )
    XX = S.fit_transform( df )
    df[ kk ]= XX

  X, y = list(), list()
  n= len(df)

  for i in range(n):
    # find the end of this pattern
    end_ix = i + n_days
    # check if we are beyond the sequence
    if end_ix > len(df)-1:
      break
    # gather input and output parts of the pattern
    seq_x = df.iloc[i:end_ix, : ].values
    seq_y = df.iloc[end_ix, 0 ]
    X.append(seq_x)
    y.append(seq_y)

  return np.array(X), np.array(y), S



def train_eval_multi(s1, s2, L, k = 'pm10.0_atm'):

  n_days, n_features = 14, len(L) # 2-week

  print('window size of', n_days, 'days', n_features , 'features')

  # split the 1d sequence into forecasting training set
  X,Y={},{}

  trn = pa_df.loc[grps.groups[s1]][:365//3]
  val = pa_df.loc[grps.groups[s1]][365//3:(365//3*2)]

  t='trn'; X[t], Y[t], Scaler = split_df(trn, n_days, L, L[0] )
  t='val'; X[t], Y[t], _ = split_df(val, n_days, L, L[0], Scaler )

  # test on a different sensor
  tst = pa_df.loc[grps.groups[s2]]
  t='tst'; X[t], Y[t], _ = split_df( tst, n_days, L, L[0], Scaler )

  #t='trn'; assert Scaler.transform( trn[L] )[n_days, 0 ] == Y[t][0]  #  trn[:15] is a concatenation of  X[t][:14] and Y[t][0]

  # https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
  model2 = Sequential()

  for t in ['trn','val','tst']:
    n_subsamples = 2
    n_days2 = n_days// n_subsamples
    if 'cnn' in mid:
      nd = n_days*n_features
      X[t] = X[t].reshape( (X[t].shape[0], nd ))

  if 'bi' in mid:
    model2.add( Bidirectional(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features))) )
    model2.add( Bidirectional(LSTM(50, activation='relu')) )

  elif 'cnn' in mid:
    model2.add( Reshape((n_days, n_features), input_shape=(nd,)))
    model2.add( Conv1D(14, kernel_size=3, activation='relu'))
    model2.add( Conv1D(14, kernel_size=3, activation='relu'))
    model2.add( BatchNormalization())
    model2.add( MaxPooling1D(pool_size=2) )
    model2.add( Flatten())

  else:
    model2.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_days, n_features)))
    model2.add(LSTM(50, activation='relu'))
  model2.add(Dense(1))

  LR=0.0001
  opt = keras.optimizers.Adam(learning_rate=LR )
  model2.compile(optimizer=opt, loss=LOSS )

  C = []
  C.append( tf.keras.callbacks.EarlyStopping(monitor="val_loss",
            min_delta=0,
            patience=0,
            verbose=0,
            mode="auto",
            baseline=None,
            restore_best_weights=False,
            start_from_epoch=0,)
  )
  t ='trn'
  h = model2.fit(X[t], Y[t], validation_data=(X['val'], Y['val']), epochs=5000, verbose=0, callbacks=C)
  hist = h.history

  plt.figure()
  for kk in hist.keys():
    plt.plot( hist[kk], label=kk )
  plt.legend()
  plt.title(L)

  print( model2.summary() )

  return eval_model(model2, X, Y )


for suffix in [ '-', '-SC1', '-SC2' ]:
  for arc in ['', 'bi', 'cnn']:

    if 1:
      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', 'prcp', 'srad']
      mid =arc+f'lstm-{len(L)}vars' + suffix
      a,b,c= train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

    if 0:
      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', 'prcp']
      mid = arc+f'lstm-{len(L)}vars'
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

      L=['pm10.0_atm', 'humidity', 'temperature', 'pressure', ]
      mid = arc+f'lstm-{len(L)}vars'
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

    if 1:
      L=['pm10.0_atm', 'srad', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'prcp', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'humidity', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])

      L=['pm10.0_atm', 'temperature', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])


      L=['pm10.0_atm', 'pressure', ]
      mid = arc+ 'lstm-' + L[-1] + suffix
      a,b,c=train_eval_multi( s1, s2, L=L )
      Res_DF.loc[len(Res_DF)] = np.array( [mid, a,b,c])
# Out:
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# Model: "sequential_75"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_112 (LSTM)             (None, 14, 50)            11400
#
#  lstm_113 (LSTM)             (None, 50)                20200
#
#  dense_75 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=97.517, RMSE=265.611, Spearman=-0.042
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_76"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_114 (LSTM)             (None, 14, 50)            10600
#
#  lstm_115 (LSTM)             (None, 50)                20200
#
#  dense_76 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=77.549, RMSE=109.632, Spearman=0.085
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_77"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_116 (LSTM)             (None, 14, 50)            10600
#
#  lstm_117 (LSTM)             (None, 50)                20200
#
#  dense_77 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.453, RMSE=10.449, Spearman=0.356
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_78"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_118 (LSTM)             (None, 14, 50)            10600
#
#  lstm_119 (LSTM)             (None, 50)                20200
#
#  dense_78 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=52.378, RMSE=59.494, Spearman=-0.034
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_79"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_120 (LSTM)             (None, 14, 50)            10600
#
#  lstm_121 (LSTM)             (None, 50)                20200
#
#  dense_79 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.838, RMSE=11.201, Spearman=0.335
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_80"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_122 (LSTM)             (None, 14, 50)            10600
#
#  lstm_123 (LSTM)             (None, 50)                20200
#
#  dense_80 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=77.779, RMSE=110.859, Spearman=0.145
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_81"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_56 (Bidirect  (None, 14, 100)           22800
#  ional)
#
#  bidirectional_57 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_81 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=379.427, RMSE=628.602, Spearman=0.232
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_82"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_58 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_59 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_82 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=65.669, RMSE=79.463, Spearman=0.156
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_83"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_60 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_61 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_83 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.427, RMSE=9.259, Spearman=0.426
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_84"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_62 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_63 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_84 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=7.616, RMSE=11.750, Spearman=0.164
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_85"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_64 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_65 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_85 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=5.693, RMSE=14.507, Spearman=0.187
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_86"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_66 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_67 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_86 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=578.505, RMSE=548.769, Spearman=-0.168
# window size of 14 days 6 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_87"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_19 (Reshape)        (None, 14, 6)             0
#
#  conv1d_38 (Conv1D)          (None, 12, 14)            266
#
#  conv1d_39 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_19 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_19 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_19 (Flatten)        (None, 70)                0
#
#  dense_87 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.561, RMSE=12.379, Spearman=-0.393
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_88"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_20 (Reshape)        (None, 14, 2)             0
#
#  conv1d_40 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_41 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_20 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_20 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_20 (Flatten)        (None, 70)                0
#
#  dense_88 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=4.974, RMSE=13.219, Spearman=-0.126
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_89"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_21 (Reshape)        (None, 14, 2)             0
#
#  conv1d_42 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_43 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_21 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_21 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_21 (Flatten)        (None, 70)                0
#
#  dense_89 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.634, RMSE=12.919, Spearman=0.089
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_90"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_22 (Reshape)        (None, 14, 2)             0
#
#  conv1d_44 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_45 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_22 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_22 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_22 (Flatten)        (None, 70)                0
#
#  dense_90 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=13.448, RMSE=22.371, Spearman=-0.211
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_91"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_23 (Reshape)        (None, 14, 2)             0
#
#  conv1d_46 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_47 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_23 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_23 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_23 (Flatten)        (None, 70)                0
#
#  dense_91 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=3.278, RMSE=14.044, Spearman=-0.109
# window size of 14 days 2 features
# dont preprocess
# dont preprocess
# dont preprocess
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_92"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_24 (Reshape)        (None, 14, 2)             0
#
#  conv1d_48 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_49 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_24 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_24 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_24 (Flatten)        (None, 70)                0
#
#  dense_92 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=7.041, RMSE=10.849, Spearman=0.282
# window size of 14 days 6 features
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_93"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_136 (LSTM)             (None, 14, 50)            11400
#
#  lstm_137 (LSTM)             (None, 50)                20200
#
#  dense_93 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 31651 (123.64 KB)
# Trainable params: 31651 (123.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.643, RMSE=0.885, Spearman=0.343
# window size of 14 days 2 features
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_94"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_138 (LSTM)             (None, 14, 50)            10600
#
#  lstm_139 (LSTM)             (None, 50)                20200
#
#  dense_94 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.593, RMSE=0.968, Spearman=-0.019
# window size of 14 days 2 features
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# <timed exec>:104: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
# Model: "sequential_95"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_140 (LSTM)             (None, 14, 50)            10600
#
#  lstm_141 (LSTM)             (None, 50)                20200
#
#  dense_95 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.603, RMSE=0.986, Spearman=-0.421
# window size of 14 days 2 features
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_96"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_142 (LSTM)             (None, 14, 50)            10600
#
#  lstm_143 (LSTM)             (None, 50)                20200
#
#  dense_96 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.670, RMSE=0.922, Spearman=0.402
# window size of 14 days 2 features
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_97"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_144 (LSTM)             (None, 14, 50)            10600
#
#  lstm_145 (LSTM)             (None, 50)                20200
#
#  dense_97 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.665, RMSE=0.900, Spearman=0.426
# window size of 14 days 2 features
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_98"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_146 (LSTM)             (None, 14, 50)            10600
#
#  lstm_147 (LSTM)             (None, 50)                20200
#
#  dense_98 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30851 (120.51 KB)
# Trainable params: 30851 (120.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.602, RMSE=0.976, Spearman=-0.212
# window size of 14 days 6 features
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_99"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_68 (Bidirect  (None, 14, 100)           22800
#  ional)
#
#  bidirectional_69 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_99 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 83301 (325.39 KB)
# Trainable params: 83301 (325.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.573, RMSE=1.008, Spearman=-0.373
# window size of 14 days 2 features
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_100"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_70 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_71 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_100 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.629, RMSE=0.883, Spearman=0.388
# window size of 14 days 2 features
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_101"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_72 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_73 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_101 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.597, RMSE=0.962, Spearman=0.178
# window size of 14 days 2 features
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_102"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_74 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_75 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_102 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.679, RMSE=0.902, Spearman=0.420
# window size of 14 days 2 features
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_103"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_76 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_77 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_103 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.619, RMSE=0.911, Spearman=0.408
# window size of 14 days 2 features
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_104"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_78 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_79 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_104 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.640, RMSE=0.883, Spearman=0.402
# window size of 14 days 6 features
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_105"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_25 (Reshape)        (None, 14, 6)             0
#
#  conv1d_50 (Conv1D)          (None, 12, 14)            266
#
#  conv1d_51 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_25 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_25 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_25 (Flatten)        (None, 70)                0
#
#  dense_105 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.825, RMSE=1.205, Spearman=-0.150
# window size of 14 days 2 features
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_106"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_26 (Reshape)        (None, 14, 2)             0
#
#  conv1d_52 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_53 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_26 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_26 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_26 (Flatten)        (None, 70)                0
#
#  dense_106 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.611, RMSE=0.975, Spearman=0.122
# window size of 14 days 2 features
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_107"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_27 (Reshape)        (None, 14, 2)             0
#
#  conv1d_54 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_55 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_27 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
# ...
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.103, RMSE=0.150, Spearman=0.419
# window size of 14 days 2 features
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_120"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_86 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_87 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_120 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.077, RMSE=0.218, Spearman=0.319
# window size of 14 days 2 features
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_121"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_88 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_89 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_121 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.128, RMSE=0.177, Spearman=-0.006
# window size of 14 days 2 features
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_122"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_90 (Bidirect  (None, 14, 100)           21200
#  ional)
#
#  bidirectional_91 (Bidirect  (None, 100)               60400
#  ional)
#
#  dense_122 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 81701 (319.14 KB)
# Trainable params: 81701 (319.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.131, RMSE=0.165, Spearman=0.290
# window size of 14 days 6 features
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_123"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_31 (Reshape)        (None, 14, 6)             0
#
#  conv1d_62 (Conv1D)          (None, 12, 14)            266
#
#  conv1d_63 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_31 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_31 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_31 (Flatten)        (None, 70)                0
#
#  dense_123 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 995 (3.89 KB)
# Trainable params: 967 (3.78 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.402, RMSE=0.525, Spearman=-0.210
# window size of 14 days 2 features
# <timed exec>:122: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_124"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_32 (Reshape)        (None, 14, 2)             0
#
#  conv1d_64 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_65 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_32 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_32 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_32 (Flatten)        (None, 70)                0
#
#  dense_124 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.157, RMSE=0.241, Spearman=-0.319
# window size of 14 days 2 features
# <timed exec>:139: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_125"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_33 (Reshape)        (None, 14, 2)             0
#
#  conv1d_66 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_67 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_33 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_33 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_33 (Flatten)        (None, 70)                0
#
#  dense_125 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.075, RMSE=0.229, Spearman=-0.256
# window size of 14 days 2 features
# <timed exec>:145: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_126"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_34 (Reshape)        (None, 14, 2)             0
#
#  conv1d_68 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_69 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_34 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_34 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_34 (Flatten)        (None, 70)                0
#
#  dense_126 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.051, RMSE=0.171, Spearman=0.241
# window size of 14 days 2 features
# <timed exec>:151: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_127"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_35 (Reshape)        (None, 14, 2)             0
#
#  conv1d_70 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_71 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_35 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_35 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_35 (Flatten)        (None, 70)                0
#
#  dense_127 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.099, RMSE=0.246, Spearman=-0.232
# window size of 14 days 2 features
# <timed exec>:156: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Model: "sequential_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_36 (Reshape)        (None, 14, 2)             0
#
#  conv1d_72 (Conv1D)          (None, 12, 14)            98
#
#  conv1d_73 (Conv1D)          (None, 10, 14)            602
#
#  batch_normalization_36 (Ba  (None, 10, 14)            56
#  tchNormalization)
#
#  max_pooling1d_36 (MaxPooli  (None, 5, 14)             0
#  ng1D)
#
#  flatten_36 (Flatten)        (None, 70)                0
#
#  dense_128 (Dense)           (None, 1)                 71
#
# =================================================================
# Total params: 827 (3.23 KB)
# Trainable params: 799 (3.12 KB)
# Non-trainable params: 28 (112.00 Byte)
# _________________________________________________________________
# None
# tst, MdAE=0.070, RMSE=0.220, Spearman=-0.074
# CPU times: user 7min 27s, sys: 4.6 s, total: 7min 32s
# Wall time: 8min 22s
# <timed exec>:162: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
LOSS
# Out:
# 'mean_squared_logarithmic_error'

# %%
# import plotly.express as px; px.line( Res_DF, x='RMSE')

# %%
def compare( met_name='MdAE'  ):
  plt.figure( figsize=(20,3))
  M = Res_DF.shape[0]
  thickness = 4
  for i,r in enumerate( Res_DF.iterrows() ):
    k = r[1]['setting']
    m = r[1][ met_name ]
    n=len(m)
    q=365//3
    a=np.arange( 0, q*n, q )
    plt.bar( a+i*thickness, m, thickness, label = k )
  plt.legend()
  plt.title( f'{met_name} of test set for each method compared' )
compare()

# %%
compare( 'RMSE' )

# %%
compare( 'R2' )

# %% [markdown]
# ## Performance measures achieved by different model-variable combinations

# %%
Res_DF.head(1000)
# Out:
#                     setting                       R2                   RMSE  \
# 0               bilstm-uni-    [0.41297666852851184]    [4.710880271911621]
# 1                 lstm-uni-     [0.4194955694631549]    [4.298763835906982]
# 2            bilstm-uni-SC1   [-0.32017872691555893]   [0.8308834228842736]
# 3              lstm-uni-SC1     [0.4379750156666843]   [0.9857533421792586]
# 4            bilstm-uni-SC2    [-0.4589748593645795]   [0.1115927691292386]
# 5              lstm-uni-SC2    [-0.3643289037561706]  [0.10307162678246712]
# 6               lstm-6vars-   [-0.04244674055994395]    [97.51746905517578]
# 7                lstm-srad-    [0.08484464104732985]    [77.54919412231445]
# 8                lstm-prcp-     [0.3556077595498197]   [3.4528005599975584]
# 9            lstm-humidity-  [-0.033794693956246194]   [52.378477966308594]
# 10        lstm-temperature-     [0.3353036093854642]    [4.837533386230469]
# 11           lstm-pressure-    [0.14497814788317806]    [77.77863122558594]
# 12            bilstm-6vars-    [0.23207276227312482]    [379.4272634277344]
# 13             bilstm-srad-    [0.15600296176191844]     [65.6686622619629]
# 14             bilstm-prcp-    [0.42581161759643454]   [3.4271911201477048]
# 15         bilstm-humidity-    [0.16372787948825027]    [7.615929565429688]
# 16      bilstm-temperature-    [0.18708717044139966]    [5.692791187286377]
# 17         bilstm-pressure-   [-0.16796572703410304]    [578.5046669921875]
# 18           cnnlstm-6vars-    [-0.3934378645011738]    [4.561309364318848]
# 19            cnnlstm-srad-   [-0.12560917410814407]    [4.973537254333496]
# 20            cnnlstm-prcp-    [0.08907430233102089]   [3.6338216915130617]
# 21        cnnlstm-humidity-   [-0.21112106489675692]   [13.447848457336425]
# 22     cnnlstm-temperature-   [-0.10861768511516126]   [3.2779235391616823]
# 23        cnnlstm-pressure-     [0.2822442818091945]   [7.0405685997009275]
# 24           lstm-6vars-SC1    [0.34299966706892077]   [0.6427473195552998]
# 25            lstm-srad-SC1  [-0.019453888901185993]   [0.5932138786593213]
# 26            lstm-prcp-SC1   [-0.42122134452700954]   [0.6026488377005736]
# 27        lstm-humidity-SC1      [0.402313160186536]   [0.6698632704030034]
# 28     lstm-temperature-SC1      [0.425561728475193]   [0.6653017477044054]
# 29        lstm-pressure-SC1   [-0.21190028605438743]    [0.602322217414439]
# 30         bilstm-6vars-SC1   [-0.37347240358998357]   [0.5726721759160134]
# 31          bilstm-srad-SC1     [0.3875741420398805]   [0.6294520819403581]
# 32          bilstm-prcp-SC1    [0.17820868350129643]   [0.5968456899828279]
# 33      bilstm-humidity-SC1    [0.42005625904612937]   [0.6785408608539399]
# 34   bilstm-temperature-SC1    [0.40801038240047244]   [0.6192451361782074]
# 35      bilstm-pressure-SC1    [0.40230150516922103]   [0.6399675722306443]
# 36        cnnlstm-6vars-SC1    [-0.1502889507730402]   [0.8252455203316947]
# 37         cnnlstm-srad-SC1     [0.1216861507800021]   [0.6107778991656037]
# 38         cnnlstm-prcp-SC1    [0.08196932052568147]   [0.6472118919512608]
# 39     cnnlstm-humidity-SC1     [0.3328144306874778]   [0.5165856370473549]
# 40  cnnlstm-temperature-SC1   [-0.15691233061289966]  [0.45774283378423986]
# 41     cnnlstm-pressure-SC1   [-0.12996135182384863]   [0.7724322331292272]
# 42           lstm-6vars-SC2    [-0.3555737657493177]  [0.15718686306098373]
# 43            lstm-srad-SC2   [-0.24092419292303255]  [0.13897570143995497]
# 44            lstm-prcp-SC2   [-0.37460169151768213]  [0.06278473683523472]
# 45        lstm-humidity-SC2   [-0.31564381517838014]   [0.0857769498590612]
# 46     lstm-temperature-SC2    [0.19587477599648717]  [0.12847601212780008]
# 47        lstm-pressure-SC2     [0.2882373194626017]  [0.12290651236171588]
# 48         bilstm-6vars-SC2     [0.2110138109874178]  [0.12183775779836048]
# 49          bilstm-srad-SC2     [0.2331856776764999]  [0.07104804437152262]
# 50          bilstm-prcp-SC2    [0.41873202707881707]  [0.10271526668592848]
# 51      bilstm-humidity-SC2    [0.31864373338513396]  [0.07742754562279663]
# 52   bilstm-temperature-SC2  [-0.005652683397768439]  [0.12770743297564024]
# 53      bilstm-pressure-SC2     [0.2903876701572167]  [0.13127414289988865]
# 54        cnnlstm-6vars-SC2    [-0.2098355442369551]   [0.4016521039496578]
# 55         cnnlstm-srad-SC2   [-0.31900850767705186]   [0.1570512566387163]
# 56         cnnlstm-prcp-SC2    [-0.2557202374044078]  [0.07524898988572327]
# 57     cnnlstm-humidity-SC2    [0.24140440738645116]  [0.05070767855899874]
# 58  cnnlstm-temperature-SC2    [-0.2319237445517403]  [0.09902681682552142]
# 59     cnnlstm-pressure-SC2   [-0.07368371321637512]  [0.06975082253266268]
#
#                      MdAE
# 0    [14.514670186674422]
# 1    [13.278993236515147]
# 2    [1.2542947815018444]
# 3    [1.7077350524289092]
# 4   [0.35864455846391263]
# 5    [0.3527681033791574]
# 6    [265.61079809079024]
# 7    [109.63156549234287]
# 8    [10.448519236649023]
# 9     [59.49370689995373]
# 10   [11.200549021161851]
# 11   [110.85855712384117]
# 12    [628.6015685026846]
# 13    [79.46305367604509]
# 14    [9.259063962075036]
# 15    [11.74983581921359]
# 16   [14.507173363014958]
# 17    [548.7689333525893]
# 18    [12.37943467902124]
# 19   [13.218969474624757]
# 20    [12.91909087881179]
# 21   [22.370727540613903]
# 22     [14.0439354560695]
# 23   [10.849370980240518]
# 24   [0.8853550792150578]
# 25   [0.9680275187529379]
# 26   [0.9856955360027339]
# 27   [0.9218448497659258]
# 28   [0.8997726610085064]
# 29   [0.9757903568963814]
# 30   [1.0084192525260234]
# 31   [0.8832906717703637]
# 32   [0.9624343163423434]
# 33   [0.9018349422068397]
# 34    [0.911148949915774]
# 35   [0.8834264106113104]
# 36   [1.2047356343537932]
# 37   [0.9750113858826158]
# 38   [0.9567162107638337]
# 39   [0.8989687324871513]
# 40   [1.0704131626444375]
# 41   [1.0796386622235545]
# 42  [0.18683686102530409]
# 43  [0.18579673553046114]
# 44   [0.2114167902417873]
# 45   [0.2311076042789802]
# 46  [0.16991107079151838]
# 47  [0.16057553355344312]
# 48   [0.2474427157789787]
# 49  [0.21518961294266745]
# 50  [0.15008476611301627]
# 51  [0.21785963888047355]
# 52   [0.1769444635206263]
# 53  [0.16500658728902406]
# 54   [0.5246596972111894]
# 55  [0.24125482523505262]
# 56  [0.22913300562084157]
# 57  [0.17091738269501283]
# 58  [0.24603242499032132]
# 59  [0.22042883012569026]
